# %% [markdown]
# # PANDAS

# %% [markdown]
# ## Introduction

# %% [markdown]
# - Pandas is a Python library used for working with data sets
# - The name "Pandas" has a reference to both "Panel Data", and "Python Data Analysis" and was created by Wes McKinney in 2008.
# - It has functions for analyzing, cleaning, exploring, and manipulating data.

# %% [markdown]
# ## Why Use Pandas?

# %% [markdown]
# - Pandas allows us to analyze big data and make conclusions based on statistical theories.
# - Pandas can clean messy data sets, and make them readable and relevant.
# - Relevant data is very important in data science.

# %% [markdown]
# ## What can Pandas do?

# %% [markdown]
# Pandas gives you answers about the data. Like:
# - Is there a correlation between two or more columns?
# - What is average value?
# - Max value?
# - Min value?
# ### Data cleaning:
# Pandas are also able to delete rows that are not relevant, or contains wrong values, like empty or NULL values. This is called cleaning the data.

# %% [markdown]
# ## Where is the Pandas codebase?
# The source code for Pandas is located at this github repository https://github.com/pandas-dev/pandas

# %% [markdown]
# # 1)Pandas Series
# - A Pandas Series is like a column in a table.
# - It is a one-dimensional array holding data of any type.
# ## Example
# Create a simple Pandas Series from a list:

# %%
import pandas as pd
a=[1,2,3,4]
sr1= pd.Series(a)
sr1
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %% [markdown]
# ### Labels
# - If nothing else is specified, the values are labeled with their index number.
# - First value has index 0, second value has index 1 etc.
# - This label can be used to access a specified value.
# ### Example
# Return the first value of the Series:

# %%
sr1[0]
# Out:
# 1

# %% [markdown]
# ### Create Your Own Labels
# - With the index argument, you can name your own labels.
# ### Example

# %%
import pandas as pd
a=[1,2,3,4]
sr2=pd.Series(a, index=["w", "x", "y","z"])
sr2
# Out:
# w    1
# x    2
# y    3
# z    4
# dtype: int64

# %% [markdown]
# #### Accessing through label

# %%
sr2["y"]
# Out:
# 3

# %% [markdown]
# ## Key/value object as Series (Dictionary)
# You can also use a key/value object, like a dictionary, when creating a Series.
#
# **Note:** The keys of the dictionary become the labels.
# ### Example
# Create a simple Pandas Series from a dictionary:

# %%
import pandas as pd
a={"1st": "Ahmad", "2nd":"Faizan", "3rd":"Fatima"}
positionholders=pd.Series(a)
positionholders
# Out:
# 1st     Ahmad
# 2nd    Faizan
# 3rd    Fatima
# dtype: object

# %%
positionholders["1st"]
# Out:
# 'Ahmad'

# %% [markdown]
# ***NOTE:*** To select only some of the items in the dictionary, use the index argument and specify only the items you want to include in the Series.
# ### Example
# Create a Series using only data from "1st" and "2nd":

# %%
import pandas as pd
a={"1st":"Ahmad","2nd":"Faizan","3rd":"Fatima"}
pos_hol=pd.Series(a, index=["1st","2nd"])
pos_hol
# Out:
# 1st     Ahmad
# 2nd    Faizan
# dtype: object

# %% [markdown]
# # 2)Pandas Dataframe
# - A Pandas DataFrame is a 2 dimensional data structure, like a 2 dimensional array, or a table with rows and columns.
# - For now consider it like an Excel sheet.
# ### Example
# Create a simple Pandas DataFrame:

# %%
import pandas as pd
data={"Name":["Rubaisha", "Malaika", "Ayesha", "Fariha"], "CGPA":[3.55, 3.58, 3.21, 3.22], "City":["BWP","JHL","SWL","SWL"], "Hobby":["Singing","Dancing","Reading","Baking"]}
#load data into dataframe object
df1= pd.DataFrame(data)
df1
# Out:
#        Name  CGPA City    Hobby
# 0  Rubaisha  3.55  BWP  Singing
# 1   Malaika  3.58  JHL  Dancing
# 2    Ayesha  3.21  SWL  Reading
# 3    Fariha  3.22  SWL   Baking

# %% [markdown]
# ### Locate Row
# - As you can see from the result above, the DataFrame is like a table with rows and columns.
# - Pandas use the loc attribute to return one or more specified row(s).
# ### Example
# return row 3: (***Note:*** *This example returns a Pandas Series.*)

# %%
df1.loc[3]
# Out:
# Name     Fariha
# CGPA       3.22
# City        SWL
# Hobby    Baking
# Name: 3, dtype: object

# %% [markdown]
# return row 1 and row 0:

# %%
df1.loc[[0,1]] #Note: When using [], the result is a Pandas DataFrame.
# Out:
#        Name  CGPA City    Hobby
# 0  Rubaisha  3.55  BWP  Singing
# 1   Malaika  3.58  JHL  Dancing

# %% [markdown]
# ## Named Indexes
# With the index argument, you can name your own indexes.
# ### Example
# Add a list of names to give each row a name:

# %%
import pandas as pd
data={"Name":["Rubaisha", "Malaika", "Ayesha", "Fariha"], "CGPA":[3.55, 3.58, 3.21, 3.22], "City":["BWP","JHL","SWL","SWL"], "Hobby":["Singing","Dancing","Reading","Baking"]}
df2=pd.DataFrame(data, index=[236,240,251,243])
df2
# Out:
#          Name  CGPA City    Hobby
# 236  Rubaisha  3.55  BWP  Singing
# 240   Malaika  3.58  JHL  Dancing
# 251    Ayesha  3.21  SWL  Reading
# 243    Fariha  3.22  SWL   Baking

# %% [markdown]
# ## Locate Named Indexes
# Use the named index in the loc attribute to return the specified row(s).
# ### Example
# **1 -** Return 251:

# %%
df2.loc[251]
# Out:
# Name      Ayesha
# CGPA        3.21
# City         SWL
# Hobby    Reading
# Name: 251, dtype: object

# %% [markdown]
# **2 -** Return 240 and 243:

# %%
df2.loc[[240,243]]
# Out:
#         Name  CGPA City    Hobby
# 240  Malaika  3.58  JHL  Dancing
# 243   Fariha  3.22  SWL   Baking

# %% [markdown]
# # 3)Pandas Read CSV Files
# - A simple way to store big data sets is to use CSV files (comma separated values files).
# - CSV files contains plain text and is a well know format that can be read by everyone including Pandas.
# - In our examples we will be using a CSV file called 'data.csv'.
# ### Example
# Load the CSV into a DataFrame:
#
# ***NOTE:*** *If you have a large DataFrame with many rows, Pandas will only return the first 5 rows, and the last 5 rows*

# %%
import pandas as pd

##df1=pd.read_csv("data.csv") - will generate error as this file is not located in the same folder i.e. pandas folder so we have to put the directory of file also

df3= pd.read_csv('C:/Users/DELL/Downloads/data.csv')
df3
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %% [markdown]
# ***TIP:*** *to print entire dataframe use to_string() method*

# %%
df3= pd.read_csv('C:/Users/DELL/Downloads/data.csv')
df3.to_string()
# Out:
# '     Duration  Pulse  Maxpulse  Calories\n0          60    110       130     409.1\n1          60    117       145     479.0\n2          60    103       135     340.0\n3          45    109       175     282.4\n4          45    117       148     406.0\n5          60    102       127     300.0\n6          60    110       136     374.0\n7          45    104       134     253.3\n8          30    109       133     195.1\n9          60     98       124     269.0\n10         60    103       147     329.3\n11         60    100       120     250.7\n12         60    106       128     345.3\n13         60    104       132     379.3\n14         60     98       123     275.0\n15         60     98       120     215.2\n16         60    100       120     300.0\n17         45     90       112       NaN\n18         60    103       123     323.0\n19         45     97       125     243.0\n20         60    108       131     364.2\n21         45    100       119     282.0\n22         60    130       101     300.0\n23         45    105       132     246.0\n24         60    102       126     334.5\n25         60    100       120     250.0\n26         60     92       118     241.0\n27         60    103       132       NaN\n28         60    100       132     280.0\n29         60    102       129     380.3\n30         60     92       115     243.0\n31         45     90       112     180.1\n32         60    101       124     299.0\n33         60     93       113     223.0\n34         60    107       136     361.0\n35         60    114       140     415.0\n36         60    102       127     300.0\n37         60    100       120     300.0\n38         60    100       120     300.0\n39         45    104       129     266.0\n40         45     90       112     180.1\n41         60     98       126     286.0\n42         60    100       122     329.4\n43         60    111       138     400.0\n44         60    111       131     397.0\n45         60     99       119     273.0\n46         60    109       153     387.6\n47         45    111       136     300.0\n48         45    108       129     298.0\n49         60    111       139     397.6\n50         60    107       136     380.2\n51         80    123       146     643.1\n52         60    106       130     263.0\n53         60    118       151     486.0\n54         30    136       175     238.0\n55         60    121       146     450.7\n56         60    118       121     413.0\n57         45    115       144     305.0\n58         20    153       172     226.4\n59         45    123       152     321.0\n60        210    108       160    1376.0\n61        160    110       137    1034.4\n62        160    109       135     853.0\n63         45    118       141     341.0\n64         20    110       130     131.4\n65        180     90       130     800.4\n66        150    105       135     873.4\n67        150    107       130     816.0\n68         20    106       136     110.4\n69        300    108       143    1500.2\n70        150     97       129    1115.0\n71         60    109       153     387.6\n72         90    100       127     700.0\n73        150     97       127     953.2\n74         45    114       146     304.0\n75         90     98       125     563.2\n76         45    105       134     251.0\n77         45    110       141     300.0\n78        120    100       130     500.4\n79        270    100       131    1729.0\n80         30    159       182     319.2\n81         45    149       169     344.0\n82         30    103       139     151.1\n83        120    100       130     500.0\n84         45    100       120     225.3\n85         30    151       170     300.0\n86         45    102       136     234.0\n87        120    100       157    1000.1\n88         45    129       103     242.0\n89         20     83       107      50.3\n90        180    101       127     600.1\n91         45    107       137       NaN\n92         30     90       107     105.3\n93         15     80       100      50.5\n94        ...

# %% [markdown]
# ### Converting a dataframe into a csv file

# %%
df2.to_csv("friends.csv")

# %% [markdown]
# ### Loading a csv file from the same location as Pandas file

# %%
df4= pd.read_csv("friends.csv") #it works here as both friends.csv and pandas are at same location
df4
# Out:
#    Unnamed: 0      Name  CGPA City    Hobby
# 0         236  Rubaisha  3.55  BWP  Singing
# 1         240   Malaika  3.58  JHL  Dancing
# 2         251    Ayesha  3.21  SWL  Reading
# 3         243    Fariha  3.22  SWL   Baking

# %% [markdown]
# ***Now if you dont want to show indexes in your excel sheet then you can remove it as:***

# %%
df2.to_csv("friends_no_index.csv", index=False)

# %% [markdown]
# ## Max Rows
# - The number of rows returned is defined in Pandas option settings.
# - You can check your system's maximum rows with the pd.options.display.max_rows statement.
# ### Example
# **1) Check the number of maximum returned rows:**

# %%
import pandas as pd
print(pd.options.display.max_rows)
# Out:
# 60

# %% [markdown]
# **2)We can also do:**

# %%
print(pd.options.display.max_info_rows) #max_info_rows
print(pd.options.display.min_rows) #min_rows
print(pd.options.display.max_columns) #max_columns
print(pd.options.display.max_info_columns) #max_info_columns
# Out:
# 1690785
# 10
# 20
# 100

# %% [markdown]
# ### Changing the max rows number
# You can change the maximum rows number with the same statement.
# ### Example
# Increase the maximum number of rows to display the entire DataFrame:

# %%
import pandas as pd
pd.options.display.max_rows=9999
df5= pd.read_csv("C:/Users/DELL/Downloads/data.csv")
df5
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# 22         60    130       101     300.0
# 23         45    105       132     246.0
# 24         60    102       126     334.5
# 25         60    100       120     250.0
# 26         60     92       118     241.0
# 27         60    103       132       NaN
# 28         60    100       132     280.0
# 29         60    102       129     380.3
# 30         60     92       115     243.0
# 31         45     90       112     180.1
# 32         60    101       124     299.0
# 33         60     93       113     223.0
# 34         60    107       136     361.0
# 35         60    114       140     415.0
# 36         60    102       127     300.0
# 37         60    100       120     300.0
# 38         60    100       120     300.0
# 39         45    104       129     266.0
# 40         45     90       112     180.1
# 41         60     98       126     286.0
# 42         60    100       122     329.4
# 43         60    111       138     400.0
# 44         60    111       131     397.0
# 45         60     99       119     273.0
# 46         60    109       153     387.6
# 47         45    111       136     300.0
# 48         45    108       129     298.0
# 49         60    111       139     397.6
# 50         60    107       136     380.2
# 51         80    123       146     643.1
# 52         60    106       130     263.0
# 53         60    118       151     486.0
# 54         30    136       175     238.0
# 55         60    121       146     450.7
# 56         60    118       121     413.0
# 57         45    115       144     305.0
# 58         20    153       172     226.4
# 59         45    123       152     321.0
# 60        210    108       160    1376.0
# 61        160    110       137    1034.4
# 62        160    109       135     853.0
# 63         45    118       141     341.0
# 64         20    110       130     131.4
# 65        180     90       130     800.4
# 66        150    105       135     873.4
# 67        150    107       130     816.0
# 68         20    106       136     110.4
# 69        300    108       143    1500.2
# 70        150     97       129    1115.0
# 71         60    109       153     387.6
# 72         90    100       127     700.0
# 73        150     97       127     953.2
# 74         45    114       146     304.0
# 75         90     98       125     563.2
# 76         45    105       134     251.0
# 77         45    110       141     300.0
# 78        120    100       130     500.4
# 79        270    100       131    1729.0
# 80         30    159       182     319.2
# 81         45    149       169     344.0
# 82         30    103       139     151.1
# 83        120    100       130     500.0
# 84         45    100       120     225.3
# 85         30    151       170     300.0
# 86         45    102       136     234.0
# 87        120    100       157    1000.1
# 88         45    129       103     242.0
# 89         20     83       107      50.3
# 90        180    101       127     600.1
# 91         45    107       137       NaN
# 92         30     90       107     105.3
# 93         15     80       100      50.5
# 94         20    150       171     127.4
# 95         20    151       168     229.4
# 96         30     95       128     128.2
# 97         25    152       168     244.2
# 98         30    109       131     188.2
# 99         90     93       124     604.1
# 100        20     95       112      77.7
# 101        90     90       110     500.0
# 102        90     90       100     500.0
# 103        90     90       100     500.4
# 104        30     92       108      92.7
# 105        30     93       128     124.0
# 106       180     90       120     800.3
# 107        30     90       120      86.2
# 108        90     90       120     500.3
# 109       210    137       184    1860.4
# 110        60    102       124     325.2
# 111        45    107       124     275.0
# 112        15    124       139     124.2
# 113        45    100       120     225.3
# 114        60    108       131     367.6
# 115        60    108       151     351.7
# 116        60    116       141     443.0
# 117        60     97       122     277.4
# 118        60    105       125       NaN
# 119        60    103       124     332.7
# 120        30    112       137     193.9
# 121        45    100       120     100.7
# 122        60    119       169     336.7
# 123        60    107       127     344.9
# 124        60    111       151     368.5
# 125        60     98       122     271.0
# 126        60     97       124     275.3
# 127        60    109       127     382.0
# 128        90     99       125     466.4
# 129        60    114       151     384.0
# 130        60    104       134     342.5
# 131        60    107       138     357.5
# 132        60    103       133     335.0
# 133        60    106       132     327.5
# 134        60    103       136     339.0
# 135        20    136       156     189.0
# 136        45    117       143     317.7
# 137        45    115       137     318.0
# 138        45    113       138     308.0
# 139        20    141       162     222.4
# 140        60    108       135     390.0
# 141        60     97       127       NaN
# 142        45    100       120     250.4
# 143        45    122       149     335.4
# 144        60    136       170     470.2
# 145        45    106       126     270.8
# 146        60    107       136     400.0
# 147        60    112       146     361.9
# 148        30    103       127     185.0
# 149        60    110       150     409.4
# 150        60    106       134     343.0
# 151        60    109       129     353.2
# 152        60    109       138     374.0
# 153        30    150       167     275.8
# 154        60    105       128     328.0
# 155        60    111       151     368.5
# 156        60     97       131     270.4
# 157        60    100       120     270.4
# 158        60    114       150     382.8
# 159        30     80       120     240.9
# 160        30     85       120     250.4
# 161        45     90       130     260.4
# 162        45     95       130     270.0
# 163        45    100       140     280.9
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4

# %% [markdown]
# #### we can also view rows using df.head() and df.tail() methods

# %%
df5.head(2) #first 2 records
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0

# %%
df5.tail(2) #last 2 records
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 167        75    120       150     320.4
# 168        75    125       150     330.4

# %% [markdown]
# #### inorder to do statistical analysis of mathematical column we cam use df.describe() method

# %%
# lets take df1 with CGPA as mathematical column
df1.describe()
# Out:
#            CGPA
# count  4.000000
# mean   3.390000
# std    0.202485
# min    3.210000
# 25%    3.217500
# 50%    3.385000
# 75%    3.557500
# max    3.580000

# %% [markdown]
# ### Changing elements
# you can change the elements of a record by accessing column as:

# %%
data= pd.read_csv("friends.csv")
data
# Out:
#    Unnamed: 0      Name  CGPA City    Hobby
# 0         236  Rubaisha  3.55  BWP  Singing
# 1         240   Malaika  3.58  JHL  Dancing
# 2         251    Ayesha  3.21  SWL  Reading
# 3         243    Fariha  3.22  SWL   Baking

# %%
data["CGPA"] #will return entire CGPA column
# Out:
# 0    3.55
# 1    3.58
# 2    3.21
# 3    3.22
# Name: CGPA, dtype: float64

# %% [markdown]
# #### Example
# change the cgpa of Ayesha from 3.21 to 3.25

# %%
data["CGPA"][2]=3.25
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_18544\1524519985.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["CGPA"][2]=3.25

# %%
data  #cgpa of ayesha now will be 3.25
# Out:
#    Unnamed: 0      Name  CGPA City    Hobby
# 0         236  Rubaisha  3.55  BWP  Singing
# 1         240   Malaika  3.58  JHL  Dancing
# 2         251    Ayesha  3.25  SWL  Reading
# 3         243    Fariha  3.22  SWL   Baking

# %%
data.to_csv("updated.csv") #new csv with updated cgpa of ayesha

# %% [markdown]
# # 4) Pandas Excel Files
# we can also access and read excel data same as csv data

# %%
import pandas as pd
ex1= pd.read_excel("excelsample.xlsx")
ex1
# Out:
#      First Name      Last Name                    Company Name  \
# 0      Rebbecca          Didio          Brandt, Jonathan F Esq
# 1        Stevie          Hallo      Landrum Temporary Services
# 2        Mariko         Stayer             Inabinet, Macre Esq
# 3       Gerardo         Woodka        Morris Downing & Sherred
# 4         Mayra           Bena              Buelt, David L Esq
# 5        Idella       Scotland  Artesian Ice & Cold Storage Co
# 6       Sherill           Klar                    Midway Hotel
# 7           Ena     Desjardiws            Selsor, Robert J Esq
# 8         Vince          Siena            Vincent J Petti & Co
# 9        Theron        Jarding            Prentiss, Paul F Esq
# 10        Amira         Chudej         Public Works Department
# 11       Marica         Tarbor        Prudential Lighting Corp
# 12       Shawna       Albrough               Wood, J Scott Esq
# 13      Paulina          Maker  Swanson Peterson Fnrl Home Inc
# 14         Rose           Jebb            Old Cider Mill Grove
# 15        Reita          Tabar               Cooper Myers Y Co
# 162                       9 Taylor Ave                       Holwell   TAS
# 163                       62 J St #450                    Combienbar   VIC
# 164                    2 Pennington St                 Port Adelaide    SA
# 165              5496 Ne Columbia Blvd                       Klemzig    SA
# 166                4244 Lucas Creek Rd                      Emu Park   QLD
# 167                 79819 Palmetto Ave                    Travancore   VIC
# 168                       7 N Glenn Rd                     Whetstone   QLD
# 169                    61 Center St #8                       Corella   QLD
# 170                  562 Nw Cornell Rd                    Humpty Doo    NT
# 171  48 General George Patton Dr #8611                   Goode Beach    WA
# 172                     9 W Passaic St                Heidelberg Rgh   VIC
# 173                   968 Delaware Ave                      Waterloo   NSW
# 174                   548 Charmonie Ln                        Minyip   VIC
# 175                    91114 Grand Ave                        Hunchy   QLD
# 176                         44 Bush St               Grosvenor Place   NSW
# 177                        6 Mahler Rd              Pacific Paradise   QLD
# 178                        1 E Main St                    Hungerford   QLD
# 179                   58 State St #998                          Boya    WA
# 180                     11408 Green St                Elizabeth West    SA
# 181                   297 8th Ave S #9                   Gumly Gumly   NSW
# 182                      1 Wyckoff Ave                    Wilmington    SA
# 183                      8 E North Ave                      Pagewood   NSW
# 184               13386 Tamarco Dr #20                       Tawonga   VIC
# 185                 70 W Market St #20                Hamlyn Heights   VIC
# 186            53247 Montgomery St #36                     Southtown   QLD
# 187               9495 Central Hwy #66                    East Bowes    WA
# 188                          2 Route 9                    Blue Haven   NSW
# 189                   75700 Academy Rd                    Cramphorne    WA
# ...
# 204            http://www.milgoindustrialinc.com.au
# 205                http://www.rogersclaymesq.com.au
# 206                 http://www.usaasbestosco.com.au
# 207                    http://www.voilsotisv.com.au
# 208             http://www.oazcommunications.com.au
# 209       http://www.elantechlgyadivsnmansol.com.au
# 210       http://www.norfolkcountynewtonlung.com.au
# 211              http://www.parkerbushlanepc.com.au
# 212         http://www.stylecraftcorporation.com.au
# 213            http://www.bennettmatthewtesq.com.au
# 214       http://www.highlandmeadowsgolfclub.com.au
# 215             http://www.nelsonmichaeljesq.com.au
# 216               http://www.henryrobertjesq.com.au
# 217                 http://www.mackraftsigns.com.au
# 218        http://www.orcostateemplfedcrdtun.com.au
# 219             http://www.johnsenrobertuesq.com.au
# 220           http://www.abegoldsteinofcfurn.com.au
# 221                http://www.rolandashcroft.com.au
# 222                http://www.villagemeadows.com.au
# 223       http://www.busadamanufacturingcorp.com.au
# 224                  http://www.airflowcoinc.com.au
# 225                     http://www.freitagpc.com.au
# 226             http://www.sawrepairsupplyco.com.au
# 227    http://www.middendorfmeatqualityfoods.com.au
# 228       http://www.eagleplywooddoormfrsinc.com.au
# 229                http://www.leighlewisresq.com.au
# 230                     http://www.barebones.com.au
# 231               http://www.avilaedwardgesq.com.au
# 232         http://www.oregonhandlingequipco.com.au
# 233           http://www.reynoldsstephenresq.com.au
# 234       http://www.creditunionoftherockies.com.au
# 235              http://www.sullivanjohnmesq.com.au
# 236                http://www.henrydlederman.com.au
# 237              http://www.burressspaigeesq.com.au
# 238                      http://www.dynetics.com.au
# 239       http://www.westpacenvironmentalinc.com.au
# 449                  http://www.testtoolsinc.com.au
# 450           http://www.rachmelcompanycpapa.com.au
# 451      http://www.hermannassocsincsafemart.com.au
# 452         http://www.palmerpublicationsinc.com.au
# 453           http://www.southernimperialinc.com.au
# 454       http://www.unitedwaterresourcesinc.com.au
# 455             http://www.burkejonathanhesq.com.au
# 456             http://www.nursesofrnewborns.com.au
# 457              http://www.paralaboratories.com.au
# 458    http://www.neworleanscreditserviceinc.com.au
# 459                  http://www.signsbyberry.com.au
# 460                 http://www.saumscottjesq.com.au
# 461            http://www.ulrichlawrencemesq.com.au
# 462            http://www.stewartlevinedavis.com.au
# 463                  http://www.barkeaterinn.com.au
# 464              http://www.reichrichardjesq.com.au
# 465                      http://www.kappusco.com.au
# 466        http://www.territeresahutchensesq.com.au
# 467         http://www.hongiwaihulbertkawano.com.au
# 468                http://www.fraserdanteltd.com.au
# 469              http://www.diecraftstamping.com.au
# 470               http://www.sakobradleytesq.com.au
# 471                http://www.countrycomfort.com.au
# 472           http://www.amberleysuitehotels.com.au
# 473              http://www.warrenleadership.com.au
# 474            http://www.alexanderdavidtesq.com.au
# 475        http://www.fairfieldinnbymarriott.com.au
# 476        http://www.skylinelodgerestaurant.com.au
# 477                http://www.aviationdesign.com.au
# 478               http://www.malmonalvinsesq.com.au
# 479       http://www.transitcargoservicesinc.com.au
# 480            http://www.comfortinnofrevere.com.au
# 481              http://www.duncanassociates.com.au
# 482   http://www.philipkingsleytrichological.com.au
# 483        http://www.burlingtonhomesofmaine.com.au
# 484               http://www.carsonscottwesq.com.au
# 485          http://www.dewittcntyfedsvngsln.com.au
# 486        http://www.artmaterialservicesinc.com.au
# 487  http://www.consolidatedmanufacturinginc.com.au
# 488           http://www.reliancecreditunion.com.au
# 489    http://www.sinclairmachineproductsinc.com.au
# 490                 http://www.kentwendymesq.com.au
# 491                 http://www.dixonericdesq.com.au
# 492              http://www.woodsignbannerco.com.au
# 493              http://www.adkinsrussellesq.com.au
# 494             http://www.danformshoestores.com.au
# 495       http://www.antietamcabletelevision.com.au
# 496               http://www.lombardibrosinc.com.au
# 497          http://www.nathanielelectronics.com.au
# 498           http://www.rodriguezjosephaesq.com.au
# 499           http://www.stillingwilliamjesq.com.au

# %% [markdown]
# # 5)Exploring Data
# - **.info()** - gives info of data i.e. column name, dtypes, no. of entries, indexes, not null values, memory usage

# %%
print(ex1.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   First Name    500 non-null    object
#  1   Last Name     500 non-null    object
#  2   Company Name  500 non-null    object
#  3   Address       500 non-null    object
#  4   City          500 non-null    object
#  5   State         500 non-null    object
#  6   Phone No      500 non-null    object
#  7   Email         500 non-null    object
#  8   Web           500 non-null    object
# dtypes: object(9)
# memory usage: 35.3+ KB
# None

# %% [markdown]
# - **.head()** - top records

# %%
print(ex1.head(10)) #will return first 10 records
# Out:
#   First Name   Last Name                    Company Name  \
# 0   Rebbecca       Didio          Brandt, Jonathan F Esq
# 1     Stevie       Hallo      Landrum Temporary Services
# 2     Mariko      Stayer             Inabinet, Macre Esq
# 3    Gerardo      Woodka        Morris Downing & Sherred
# 4      Mayra        Bena              Buelt, David L Esq
# 5     Idella    Scotland  Artesian Ice & Cold Storage Co
# 6    Sherill        Klar                    Midway Hotel
# 7        Ena  Desjardiws            Selsor, Robert J Esq
# 8      Vince       Siena            Vincent J Petti & Co
# 9     Theron     Jarding            Prentiss, Paul F Esq
#
#                  Address             City State      Phone No  \
# 0          171 E 24th St            Leith   TAS  03-8174-9123
# 1         22222 Acoma St          Proston   QLD  07-9997-3366
# 2  534 Schoenborn St #51            Hamel    WA  08-5558-9019
# 3      69206 Jackson Ave         Talmalmo   NSW  02-6044-4682
# 4      808 Glen Cove Ave        Lane Cove   NSW  02-1455-6085
# 5       373 Lafayette St      Cartmeticup    WA  08-7868-1355
# 6          87 Sylvan Ave           Nyamup    WA  08-6522-8931
# 7        60562 Ky Rt 321  Bendick Murrell   NSW  02-5226-9402
# 8           70 S 18th Pl       Purrawunda   QLD  07-3184-9989
# 9      8839 Ventura Blvd      Blanchetown    SA  08-6890-4661
#
#                               Email  \
# 0       rebbecca.didio@didio.com.au
# 1          stevie.hallo@hotmail.com
# 2         mariko_stayer@hotmail.com
# 3        gerardo_woodka@hotmail.com
# 4              mayra.bena@gmail.com
# 5                idella@hotmail.com
# 6                 sklar@hotmail.com
# 7  ena_desjardiws@desjardiws.com.au
# 8             vince_siena@yahoo.com
# 9              tjarding@hotmail.com
#
#                                           Web
# 0        http://www.brandtjonathanfesq.com.au
# 1  http://www.landrumtemporaryservices.com.au
# 2          http://www.inabinetmacreesq.com.au
# 3      http://www.morrisdowningsherred.com.au
# 4            http://www.bueltdavidlesq.com.au
# 5  http://www.artesianicecoldstorageco.com.au
# 6               http://www.midwayhotel.com.au
# 7          http://www.selsorrobertjesq.com.au
# 8           http://www.vincentjpettico.com.au
# 9          http://www.prentisspaulfesq.com.au

# %% [markdown]
# - **.tail()** - bottom records

# %%
print(ex1.tail(10)) #will return last 10 records
# Out:
#     First Name Last Name               Company Name                 Address  \
# 490  Margurite      Okon          Kent, Wendy M Esq          32 Broadway St
# 491      Artie     Saine          Dixon, Eric D Esq      41 Washington Blvd
# 492      Major  Studwell      Wood Sign & Banner Co      5 Buford Hwy Ne #3
# 493   Veronika  Buchauer        Adkins, Russell Esq              6 Flex Ave
# 494  Christene    Cisney        Danform Shoe Stores      21058 Massillon Rd
# 495      Miles   Feldner  Antietam Cable Television  28465 Downey Ave #4238
# 496      Julio     Mikel          Lombardi Bros Inc     2803 N Catalina Ave
# 497       Aide     Ghera      Nathaniel Electronics       22 Livingston Ave
# 498     Noelia  Brackett    Rodriguez, Joseph A Esq      403 Conn Valley Rd
# 499     Lenora  Delacruz    Stilling, William J Esq          5400 Market St
#
#              City State      Phone No                              Email  \
# 490        Lanena   TAS  03-9721-7313         margurite.okon@hotmail.com
# 491     Cora Lynn   VIC  03-3457-2524              artie_saine@yahoo.com
# 492        Allora   QLD  07-1377-6898                    major@gmail.com
# 493   Willow Tree   NSW  02-4202-5191  veronika.buchauer@buchauer.net.au
# 494  Keilor Downs   VIC  03-3630-2467              christene@hotmail.com
# 495     Barringun   QLD  07-8561-5894                  miles@hotmail.com
# 496       Pilliga   NSW  02-6995-9902           julio.mikel@mikel.net.au
# 497        Rhodes   NSW  02-3738-7508            aide.ghera@ghera.com.au
# 498    Castletown    WA  08-3773-3770             noelia@brackett.net.au
# 499        Turill   NSW  02-7862-5151             lenora@delacruz.net.au
#
#                                            Web
# 490            http://www.kentwendymesq.com.au
# 491            http://www.dixonericdesq.com.au
# 492         http://www.woodsignbannerco.com.au
# 493         http://www.adkinsrussellesq.com.au
# 494        http://www.danformshoestores.com.au
# 495  http://www.antietamcabletelevision.com.au
# 496          http://www.lombardibrosinc.com.au
# 497     http://www.nathanielelectronics.com.au
# 498      http://www.rodriguezjosephaesq.com.au
# 499      http://www.stillingwilliamjesq.com.au

# %% [markdown]
# - **.describe()** - inorder to do statistical analysis of mathematical column we cam use .describe() method

# %%
print(ex1.describe())
# Out:
#        First Name Last Name  Company Name        Address           City State  \
# count         500       500           500            500            500   500
# unique        484       500           498            500            480     8
# top        Gerald     Didio  House Of Ing  171 E 24th St  Varsity Lakes   NSW
# freq            2         1             2              1              2   125
#
#             Phone No                        Email  \
# count            500                          500
# unique           500                          500
# top     03-8174-9123  rebbecca.didio@didio.com.au
# freq               1                            1
#
#                                  Web
# count                            500
# unique                           498
# top     http://www.houseofing.com.au
# freq                               2

# %% [markdown]
# - **.isnull()** - to find null values

# %%
print(ex1.isnull()) #returns TRUE for null values
# Out:
#      First Name  Last Name  Company Name  Address   City  State  Phone No  \
# 0         False      False         False    False  False  False     False
# 1         False      False         False    False  False  False     False
# 2         False      False         False    False  False  False     False
# 3         False      False         False    False  False  False     False
# 4         False      False         False    False  False  False     False
# 5         False      False         False    False  False  False     False
# 6         False      False         False    False  False  False     False
# 7         False      False         False    False  False  False     False
# 8         False      False         False    False  False  False     False
# 9         False      False         False    False  False  False     False
# 10        False      False         False    False  False  False     False
# 11        False      False         False    False  False  False     False
# 12        False      False         False    False  False  False     False
# 13        False      False         False    False  False  False     False
# 14        False      False         False    False  False  False     False
# 15        False      False         False    False  False  False     False
# 16        False      False         False    False  False  False     False
# 17        False      False         False    False  False  False     False
# 18        False      False         False    False  False  False     False
# 19        False      False         False    False  False  False     False
# 20        False      False         False    False  False  False     False
# 21        False      False         False    False  False  False     False
# 22        False      False         False    False  False  False     False
# 23        False      False         False    False  False  False     False
# 24        False      False         False    False  False  False     False
# 25        False      False         False    False  False  False     False
# 26        False      False         False    False  False  False     False
# 27        False      False         False    False  False  False     False
# 28        False      False         False    False  False  False     False
# 29        False      False         False    False  False  False     False
# 30        False      False         False    False  False  False     False
# 31        False      False         False    False  False  False     False
# 32        False      False         False    False  False  False     False
# 33        False      False         False    False  False  False     False
# 34        False      False         False    False  False  False     False
# 35        False      False         False    False  False  False     False
# 36        False      False         False    False  False  False     False
# 37        False      False         False    False  False  False     False
# 38        False      False         False    False  False  False     False
# 39        False      False         False    False  False  False     False
# 40        False      False         False    False  False  False     False
# 41        False      False         False    False  False  False     False
# 42        False      False         False    False  False  False     False
# Phone No        0
# Email           0
# Web             0
# dtype: int64

# %% [markdown]
# # 6)Handling Duplicates
# - Duplicate rows are rows that have been registered more than one time.
# - To discover duplicates, we can use the duplicated() method.
# - The duplicated() method returns a Boolean values for each row.
# ### Example
# Returns True for every row that is a duplicate, otherwise False:

# %%
import pandas as pd
ds1= pd.read_csv('C:/Users/DELL/Desktop/jupyter projects/friends.csv')
ds1
# Out:
#    RollNum      Name  CGPA City    Hobby
# 0    236.0  Rubaisha  3.55  BWP  Singing
# 1    240.0   Malaika  3.58  JHL  Dancing
# 2    251.0    Ayesha  3.21  SWL  Reading
# 3    243.0    Fariha  3.22  SWL   Baking
# 4    236.0  Rubaisha  3.55  BWP  Singing
# 5      NaN    Maryam  3.87  KRC  Reading

# %%
ds1['RollNum'].duplicated().sum() #there is only 1 duplicated record on the basis of primary key RollNum
# Out:
# 1

# %%
ds1['RollNum'].duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5    False
# Name: RollNum, dtype: bool

# %% [markdown]
# ## Removing Duplicates
# To remove duplicates, use the drop_duplicates() method.

# %%
ds1.drop_duplicates('RollNum')
# Out:
#    RollNum      Name  CGPA City    Hobby
# 0    236.0  Rubaisha  3.55  BWP  Singing
# 1    240.0   Malaika  3.58  JHL  Dancing
# 2    251.0    Ayesha  3.21  SWL  Reading
# 3    243.0    Fariha  3.22  SWL   Baking
# 5      NaN    Maryam  3.87  KRC  Reading

# %% [markdown]
# # 7)Missing Data / Empty Cells
# - Empty cells can potentially give you a wrong result when you analyze data.
# ## Remove Rows
# - One way to deal with empty cells is to remove rows that contain empty cells.
# - This is usually OK, since data sets can be very big, and removing a few rows will not have a big impact on the result.
# ### Example
# Return a new Data Frame with no empty cells:

# %%
import pandas as pd
ds2= pd.read_csv("C:/Users/DELL/Desktop/jupyter projects/friends1.csv")
ds2
# Out:
#    RollNum      Name  CGPA City     Hobby
# 0      236  Rubaisha  3.55  BWP   Singing
# 1      240   Malaika  3.58  JHL   Dancing
# 2      251    Ayesha  3.21  SWL   Reading
# 3      243    Fariha  3.22  SWL    Baking
# 4      216    Maryam  3.87  KRC   Reading
# 5      229   Malaika  3.51  SWL       NaN
# 6      230   Sabrina  3.33  NaN  painting
# 7      211     Usman   NaN  LHR   Cycling
# 8      221       NaN  3.00  FSL   Gymming

# %%
ds2.isnull().sum() #identifying null values
# Out:
# RollNum    0
# Name       1
# CGPA       1
# City       1
# Hobby      1
# dtype: int64

# %%
ds2.dropna() #Note: By default, the dropna() method returns a new DataFrame, and will not change the original.
# Out:
#    RollNum      Name  CGPA City    Hobby
# 0      236  Rubaisha  3.55  BWP  Singing
# 1      240   Malaika  3.58  JHL  Dancing
# 2      251    Ayesha  3.21  SWL  Reading
# 3      243    Fariha  3.22  SWL   Baking
# 4      216    Maryam  3.87  KRC  Reading

# %%
#If you want to change the original DataFrame, use the inplace = True argument

import pandas as pd
ds2= pd.read_csv("C:/Users/DELL/Desktop/jupyter projects/friends1.csv")
ds2

ds2.dropna(inplace=True)
ds2
# Out:
#    RollNum      Name  CGPA City    Hobby
# 0      236  Rubaisha  3.55  BWP  Singing
# 1      240   Malaika  3.58  JHL  Dancing
# 2      251    Ayesha  3.21  SWL  Reading
# 3      243    Fariha  3.22  SWL   Baking
# 4      216    Maryam  3.87  KRC  Reading

# %% [markdown]
# ## Drawback of using dropna() method
# - changes the count of employee i.e the correct employee count is 9 but after using dropna() method all rows containing even a single empty cell are being completely deleted from the data set and hence the employee count reduces from 9 to 5 which is not correct
# - we cant use dropna() method in all situations, in some cases we have to replace the null values with some data i.e. we have to fill null cells using replace() method

# %% [markdown]
# ### Replacing empty cells with some values
# - Another way of dealing with empty cells is to insert a new value instead.
# - This way you do not have to delete entire rows just because of some empty cells.
# - The **fillna()** method allows us to replace empty cells with a value:
#   #### Example
#   Replace NULL values with the number 130:

# %%
import pandas as pd
ds3= pd.read_csv("C:/Users/DELL/Desktop/jupyter projects/friends1.csv")
ds3
# Out:
#    RollNum      Name  CGPA City     Hobby
# 0      236  Rubaisha  3.55  BWP   Singing
# 1      240   Malaika  3.58  JHL   Dancing
# 2      251    Ayesha  3.21  SWL   Reading
# 3      243    Fariha  3.22  SWL    Baking
# 4      216    Maryam  3.87  KRC   Reading
# 5      229   Malaika  3.51  SWL       NaN
# 6      230   Sabrina  3.33  NaN  painting
# 7      211     Usman   NaN  LHR   Cycling
# 8      221       NaN  3.00  FSL   Gymming

# %%
ds3.fillna(130, inplace= True) #ds3.fillna("running", inplace=True) will store "running" in all null cells irrespective of their data type

# %%
ds3
# Out:
#    RollNum      Name    CGPA City     Hobby
# 0      236  Rubaisha    3.55  BWP   Singing
# 1      240   Malaika    3.58  JHL   Dancing
# 2      251    Ayesha    3.21  SWL   Reading
# 3      243    Fariha    3.22  SWL    Baking
# 4      216    Maryam    3.87  KRC   Reading
# 5      229   Malaika    3.51  SWL       130
# 6      230   Sabrina    3.33  130  painting
# 7      211     Usman  130.00  LHR   Cycling
# 8      221       130    3.00  FSL   Gymming

# %% [markdown]
# #### replace() method
# it can also be done using replace() method

# %%
import pandas as pd
ds3= pd.read_csv("C:/Users/DELL/Desktop/jupyter projects/friends1.csv")
ds3
# Out:
#    RollNum      Name  CGPA City     Hobby
# 0      236  Rubaisha  3.55  BWP   Singing
# 1      240   Malaika  3.58  JHL   Dancing
# 2      251    Ayesha  3.21  SWL   Reading
# 3      243    Fariha  3.22  SWL    Baking
# 4      216    Maryam  3.87  KRC   Reading
# 5      229   Malaika  3.51  SWL       NaN
# 6      230   Sabrina  3.33  NaN  painting
# 7      211     Usman   NaN  LHR   Cycling
# 8      221       NaN  3.00  FSL   Gymming

# %%
import numpy as np
ds3.replace(np.nan, "running")
# Out:
#    RollNum      Name     CGPA     City     Hobby
# 0      236  Rubaisha     3.55      BWP   Singing
# 1      240   Malaika     3.58      JHL   Dancing
# 2      251    Ayesha     3.21      SWL   Reading
# 3      243    Fariha     3.22      SWL    Baking
# 4      216    Maryam     3.87      KRC   Reading
# 5      229   Malaika     3.51      SWL   running
# 6      230   Sabrina     3.33  running  painting
# 7      211     Usman  running      LHR   Cycling
# 8      221   running      3.0      FSL   Gymming

# %% [markdown]
# ### Replace Only For Specified Columns
# - The example above replaces all empty cells in the whole Data Frame.
# - To only replace empty values for one column, specify the column name for the DataFrame:
#  #### Example
#  Replace NULL values in the "Hobby" columns with the "swiming"

# %%
import pandas as pd
ds3= pd.read_csv("C:/Users/DELL/Desktop/jupyter projects/friends1.csv")
ds3
# Out:
#    RollNum      Name  CGPA City     Hobby
# 0      236  Rubaisha  3.55  BWP   Singing
# 1      240   Malaika  3.58  JHL   Dancing
# 2      251    Ayesha  3.21  SWL   Reading
# 3      243    Fariha  3.22  SWL    Baking
# 4      216    Maryam  3.87  KRC   Reading
# 5      229   Malaika  3.51  SWL       NaN
# 6      230   Sabrina  3.33  NaN  painting
# 7      211     Usman   NaN  LHR   Cycling
# 8      221       NaN  3.00  FSL   Gymming

# %% [markdown]
# #### fillna():

# %%
#ds3["Hobby"].fillna("swiming", inplace = True)
#ds3
ds3.fillna({"Hobby":"swiming"}, inplace=True)
ds3
# Out:
#    RollNum      Name  CGPA City     Hobby
# 0      236  Rubaisha  3.55  BWP   Singing
# 1      240   Malaika  3.58  JHL   Dancing
# 2      251    Ayesha  3.21  SWL   Reading
# 3      243    Fariha  3.22  SWL    Baking
# 4      216    Maryam  3.87  KRC   Reading
# 5      229   Malaika  3.51  SWL   swiming
# 6      230   Sabrina  3.33  NaN  painting
# 7      211     Usman   NaN  LHR   Cycling
# 8      221       NaN  3.00  FSL   Gymming

# %%
import pandas as pd
ds3= pd.read_csv("C:/Users/DELL/Desktop/jupyter projects/friends1.csv")
ds3
# Out:
#    RollNum      Name  CGPA City     Hobby
# 0      236  Rubaisha  3.55  BWP   Singing
# 1      240   Malaika  3.58  JHL   Dancing
# 2      251    Ayesha  3.21  SWL   Reading
# 3      243    Fariha  3.22  SWL    Baking
# 4      216    Maryam  3.87  KRC   Reading
# 5      229   Malaika  3.51  SWL       NaN
# 6      230   Sabrina  3.33  NaN  painting
# 7      211     Usman   NaN  LHR   Cycling
# 8      221       NaN  3.00  FSL   Gymming

# %% [markdown]
# #### replace():

# %%
import numpy as np
ds3["Hobby"]=ds3["Hobby"].replace(np.nan, "swiming")
ds3
# Out:
#    RollNum      Name  CGPA City     Hobby
# 0      236  Rubaisha  3.55  BWP   Singing
# 1      240   Malaika  3.58  JHL   Dancing
# 2      251    Ayesha  3.21  SWL   Reading
# 3      243    Fariha  3.22  SWL    Baking
# 4      216    Maryam  3.87  KRC   Reading
# 5      229   Malaika  3.51  SWL   swiming
# 6      230   Sabrina  3.33  NaN  painting
# 7      211     Usman   NaN  LHR   Cycling
# 8      221       NaN  3.00  FSL   Gymming

# %% [markdown]
# ##### fill empty cells in city column with "ISBD" using fillna()

# %%
#ds3["City"].fillna("ISBD", inplace=True)
#print(ds3)
ds3.fillna({"City":"ISBD"}, inplace=True)
print(ds3)
#import numpy as np
#ds3["City"]=ds3["City"].replace(np.nan, "ISBD")
#print(ds3)
# Out:
#    RollNum      Name  CGPA  City     Hobby
# 0      236  Rubaisha  3.55   BWP   Singing
# 1      240   Malaika  3.58   JHL   Dancing
# 2      251    Ayesha  3.21   SWL   Reading
# 3      243    Fariha  3.22   SWL    Baking
# 4      216    Maryam  3.87   KRC   Reading
# 5      229   Malaika  3.51   SWL   swiming
# 6      230   Sabrina  3.33  ISBD  painting
# 7      211     Usman   NaN   LHR   Cycling
# 8      221       NaN  3.00   FSL   Gymming

# %% [markdown]
# #### replace empty cells in CGPA with 3.90 using replace()

# %%
import numpy as np
ds3["CGPA"]=ds3["CGPA"].replace(np.nan, 3.90)
ds3
# Out:
#    RollNum      Name  CGPA  City     Hobby
# 0      236  Rubaisha  3.55   BWP   Singing
# 1      240   Malaika  3.58   JHL   Dancing
# 2      251    Ayesha  3.21   SWL   Reading
# 3      243    Fariha  3.22   SWL    Baking
# 4      216    Maryam  3.87   KRC   Reading
# 5      229   Malaika  3.51   SWL   swiming
# 6      230   Sabrina  3.33  ISBD  painting
# 7      211     Usman  3.90   LHR   Cycling
# 8      221       NaN  3.00   FSL   Gymming

# %% [markdown]
# ## Replace Using Mean, Median, or Mode
# - A common way to replace empty cells, is to calculate the mean, median or mode value of the column.
# - Pandas uses the mean() median() and mode() methods to calculate the respective values for a specified column:
# #### Example
# - **i->Calculate the MEAN, and replace any empty values with it:**

# %%
import pandas as pd
ds3= pd.read_csv("C:/Users/DELL/Desktop/jupyter projects/friends1.csv")
ds3
# Out:
#    RollNum      Name  CGPA City     Hobby
# 0      236  Rubaisha  3.55  BWP   Singing
# 1      240   Malaika  3.58  JHL   Dancing
# 2      251    Ayesha  3.21  SWL   Reading
# 3      243    Fariha  3.22  SWL    Baking
# 4      216    Maryam  3.87  KRC   Reading
# 5      229   Malaika  3.51  SWL       NaN
# 6      230   Sabrina  3.33  NaN  painting
# 7      211     Usman   NaN  LHR   Cycling
# 8      221       NaN  3.00  FSL   Gymming

# %%
x= ds3["CGPA"].mean() #Mean = the average value (the sum of all values divided by number of values).

# %%
x
# Out:
# 3.40875

# %%
import numpy as np
ds3["CGPA"]=ds3["CGPA"].replace(np.nan, x)
ds3
# Out:
#    RollNum      Name     CGPA City     Hobby
# 0      236  Rubaisha  3.55000  BWP   Singing
# 1      240   Malaika  3.58000  JHL   Dancing
# 2      251    Ayesha  3.21000  SWL   Reading
# 3      243    Fariha  3.22000  SWL    Baking
# 4      216    Maryam  3.87000  KRC   Reading
# 5      229   Malaika  3.51000  SWL       NaN
# 6      230   Sabrina  3.33000  NaN  painting
# 7      211     Usman  3.40875  LHR   Cycling
# 8      221       NaN  3.00000  FSL   Gymming

# %% [markdown]
# **- Calculate the MEDIAN, and replace any empty values with it**

# %%
y= ds3["RollNum"].median() #Median = the value in the middle, after you have sorted all values ascending.
y
# Out:
# 230.0

# %%
ds3["RollNum"].fillna(y, inplace=True)
ds3
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_18544\3163243179.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ds3["RollNum"].fillna(y, inplace=True)
#    RollNum      Name     CGPA City     Hobby
# 0      236  Rubaisha  3.55000  BWP   Singing
# 1      240   Malaika  3.58000  JHL   Dancing
# 2      251    Ayesha  3.21000  SWL   Reading
# 3      243    Fariha  3.22000  SWL    Baking
# 4      216    Maryam  3.87000  KRC   Reading
# 5      229   Malaika  3.51000  SWL       NaN
# 6      230   Sabrina  3.33000  NaN  painting
# 7      211     Usman  3.40875  LHR   Cycling
# 8      221       NaN  3.00000  FSL   Gymming

# %%
z=ds3["CGPA"].mode()[0] #Mode = the value that appears most frequently.

# %%
z
# Out:
# 3.0

# %% [markdown]
# ### bfill
# to fill an empty cell with the value in next lower cell we use backward fill i.e. "bfill" with filllna() method

# %%
ds3
# Out:
#    RollNum      Name     CGPA City     Hobby
# 0      236  Rubaisha  3.55000  BWP   Singing
# 1      240   Malaika  3.58000  JHL   Dancing
# 2      251    Ayesha  3.21000  SWL   Reading
# 3      243    Fariha  3.22000  SWL    Baking
# 4      216    Maryam  3.87000  KRC   Reading
# 5      229   Malaika  3.51000  SWL       NaN
# 6      230   Sabrina  3.33000  NaN  painting
# 7      211     Usman  3.40875  LHR   Cycling
# 8      221       NaN  3.00000  FSL   Gymming

# %%
#ds3.fillna(method="bfill")
ds3.bfill()
# Out:
#    RollNum      Name     CGPA City     Hobby
# 0      236  Rubaisha  3.55000  BWP   Singing
# 1      240   Malaika  3.58000  JHL   Dancing
# 2      251    Ayesha  3.21000  SWL   Reading
# 3      243    Fariha  3.22000  SWL    Baking
# 4      216    Maryam  3.87000  KRC   Reading
# 5      229   Malaika  3.51000  SWL  painting
# 6      230   Sabrina  3.33000  LHR  painting
# 7      211     Usman  3.40875  LHR   Cycling
# 8      221       NaN  3.00000  FSL   Gymming

# %% [markdown]
# ### ffill
# to fill an empty cell with the value in upper cell we use forward fill i.e. "ffill" with filllna() method

# %%
ds3
# Out:
#    RollNum      Name     CGPA City     Hobby
# 0      236  Rubaisha  3.55000  BWP   Singing
# 1      240   Malaika  3.58000  JHL   Dancing
# 2      251    Ayesha  3.21000  SWL   Reading
# 3      243    Fariha  3.22000  SWL    Baking
# 4      216    Maryam  3.87000  KRC   Reading
# 5      229   Malaika  3.51000  SWL       NaN
# 6      230   Sabrina  3.33000  NaN  painting
# 7      211     Usman  3.40875  LHR   Cycling
# 8      221       NaN  3.00000  FSL   Gymming

# %%
#ds3.fillna(method="ffill")
ds3.ffill()
# Out:
#    RollNum      Name     CGPA City     Hobby
# 0      236  Rubaisha  3.55000  BWP   Singing
# 1      240   Malaika  3.58000  JHL   Dancing
# 2      251    Ayesha  3.21000  SWL   Reading
# 3      243    Fariha  3.22000  SWL    Baking
# 4      216    Maryam  3.87000  KRC   Reading
# 5      229   Malaika  3.51000  SWL   Reading
# 6      230   Sabrina  3.33000  SWL  painting
# 7      211     Usman  3.40875  LHR   Cycling
# 8      221     Usman  3.00000  FSL   Gymming

# %% [markdown]
# ## Conclusion:
# to conclude, inorder to handle empty cells , dropna() is not the best approach, instead
# - in case of numeric data, we can use mean, median and mode methods for handling empty cells
# - in case of text data we can use bfill and ffill to handle empty cells
# these methods are not accurate but atleast provide us better understanding of data rather than deletion of data

# %% [markdown]
# # 8) .loc[] and .iloc[]
# ## .loc[]
# - Pandas DataFrame.loc attribute accesses a group of rows and columns by label(s) or a boolean array in the given Pandas DataFrame.
# - **Example 1: Select a Single Row and Column By Label using loc[]**

# %%
import pandas as pd
data= {"Name":["Fatima", "Ali", "Hamza","Amna", "Asim"], "Age":[15, 17, 19, 20, 20],"Class":[9, 5,8,12,12], "fav_clr":["black","yellow","green","magenta","purple"]}
df=pd.DataFrame(data, index=['Row_1', 'Row_2', 'Row_3', 'Row_4', 'Row_5'])
df
# Out:
#          Name  Age  Class  fav_clr
# Row_1  Fatima   15      9    black
# Row_2     Ali   17      5   yellow
# Row_3   Hamza   19      8    green
# Row_4    Amna   20     12  magenta
# Row_5    Asim   20     12   purple

# %%
#selecting single row and column
result1=df.loc['Row_4', 'Name']
result1
# Out:
# 'Amna'

# %% [markdown]
# - **Example 2: Select Multiple Rows and Columns**

# %%
result2= df.loc[:, ['Name', 'Class']]
result2
# Out:
#          Name  Class
# Row_1  Fatima      9
# Row_2     Ali      5
# Row_3   Hamza      8
# Row_4    Amna     12
# Row_5    Asim     12

# %% [markdown]
# - **Example 3: Select Between Two Rows or Columns**

# %%
#r0w 2 to row 4
print("Selected rows:")
result3=df.loc['Row_2':'Row_4']
print(result3)
print("selected columns:")
result4=df.loc[:, "Age":"fav_clr"]
print(result4)
print("Combining the two:")
result5=df.loc["Row_2":"Row_4", "Age":"fav_clr"]
print(result5)
# Out:
# Selected rows:
#         Name  Age  Class  fav_clr
# Row_2    Ali   17      5   yellow
# Row_3  Hamza   19      8    green
# Row_4   Amna   20     12  magenta
# selected columns:
#        Age  Class  fav_clr
# Row_1   15      9    black
# Row_2   17      5   yellow
# Row_3   19      8    green
# Row_4   20     12  magenta
# Row_5   20     12   purple
# Combining the two:
#        Age  Class  fav_clr
# Row_2   17      5   yellow
# Row_3   19      8    green
# Row_4   20     12  magenta

# %% [markdown]
# - **Example 4: Select Alternate Rows or Columns**

# %%
#alternate rows
print("Selecting alternate rows:")
result6= df.loc[::2]
print(result6)
#alternate columns
print("selecting alternate columns:")
result7= df.loc[:, ::2]
print(result7)
#combining
print("Combining the two:")
result8= df.loc[::2, ::2]
print(result8)
# Out:
# Selecting alternate rows:
#          Name  Age  Class fav_clr
# Row_1  Fatima   15      9   black
# Row_3   Hamza   19      8   green
# Row_5    Asim   20     12  purple
# selecting alternate columns:
#          Name  Class
# Row_1  Fatima      9
# Row_2     Ali      5
# Row_3   Hamza      8
# Row_4    Amna     12
# Row_5    Asim     12
# Combining the two:
#          Name  Class
# Row_1  Fatima      9
# Row_3   Hamza      8
# Row_5    Asim     12

# %% [markdown]
# - **Example 5: Using Conditions with Pandas loc**

# %%
df2= pd.DataFrame({"A": [12, 4, 5, None, 1],
                   "B": [7, 2, 54, 3, None],
                   "C": [20, 16, 11, 3, 8],
                   "D": [14, 3, None, 2, 6]}, index=["row_1", "row_2","row_3","row_4","row_5"])
print(df2)
# Out:
#           A     B   C     D
# row_1  12.0   7.0  20  14.0
# row_2   4.0   2.0  16   3.0
# row_3   5.0  54.0  11   NaN
# row_4   NaN   3.0   3   2.0
# row_5   1.0   NaN   8   6.0

# %%
#Select rows where column 'A' is greater than 5
print("rows where column 'A' is greater than 5:")
result9= df2.loc[df2['A']>5]
print(result9)
#Select rows where column 'B' is not null
print("rows where column 'B' is not null")
result10= df2.loc[df2['B'].notnull()]
print(result10)
# Out:
# rows where column 'A' is greater than 5:
#           A    B   C     D
# row_1  12.0  7.0  20  14.0
# rows where column 'B' is not null
#           A     B   C     D
# row_1  12.0   7.0  20  14.0
# row_2   4.0   2.0  16   3.0
# row_3   5.0  54.0  11   NaN
# row_4   NaN   3.0   3   2.0

# %% [markdown]
# ## .iloc[]
# - In the Python Pandas library, .iloc[] is an indexer used for integer-location-based indexing of data in a DataFrame.
# - It allows users to select specific rows and columns by providing integer indices, making it a valuable tool for data manipulation and extraction based on numerical positions within the DataFrame.
# - This indexer is particularly useful when you want to access or manipulate data using integer-based positional indexing rather than labels.
# - **Example 1: Selecting rows using Pandas .iloc and .loc[]**

# %%
import pandas as pd
data= pd.read_csv("C:/Users/DELL/Downloads/nba.csv")
#using loc[]
print("retrieving row 3 using loc[] method:")
rloc= data.loc[3]
print(rloc)
#using iloc[]
print("retrieving row 3 using iloc[] method:")
riloc= data.iloc[3]
print(riloc)
#checking both
print("Checking if both results are same or not:")
rloc == riloc
# Out:
# retrieving row 3 using loc[] method:
# Name           R.J. Hunter
# Team        Boston Celtics
# Number                28.0
# Position                SG
# Age                   22.0
# Height                 6-5
# Weight               185.0
# College      Georgia State
# Salary           1148640.0
# Name: 3, dtype: object
# retrieving row 3 using iloc[] method:
# Name           R.J. Hunter
# Team        Boston Celtics
# Number                28.0
# Position                SG
# Age                   22.0
# Height                 6-5
# Weight               185.0
# College      Georgia State
# Salary           1148640.0
# Name: 3, dtype: object
# Checking if both results are same or not:
# Name        True
# Team        True
# Number      True
# Position    True
# Age         True
# Height      True
# Weight      True
# College     True
# Salary      True
# Name: 3, dtype: bool

# %% [markdown]
# - **Example 2: Selecting Multiple Rows using Pandas .iloc[] in Python**

# %%
#through list
print("Selecting multiple rows by passing a list:")
res1= data.iloc[[4,5,6,7]]
print(res1)
#range method
print("Selecting multiple rows using range method:")
res2= data.iloc[4:8]
print(res2)
#checking results
print("Checking if both results are same:")
res1 == res2
# Out:
# Selecting multiple rows by passing a list:
#             Name            Team  Number Position   Age Height  Weight  \
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7   Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
#
#    College      Salary
# 4      NaN   5000000.0
# 5      NaN  12000000.0
# 6      LSU   1170960.0
# 7  Gonzaga   2165160.0
# Selecting multiple rows using range method:
#             Name            Team  Number Position   Age Height  Weight  \
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7   Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
#
#    College      Salary
# 4      NaN   5000000.0
# 5      NaN  12000000.0
# 6      LSU   1170960.0
# 7  Gonzaga   2165160.0
# Checking if both results are same:
#    Name  Team  Number  Position   Age  Height  Weight  College  Salary
# 4  True  True    True      True  True    True    True    False    True
# 5  True  True    True      True  True    True    True    False    True
# 6  True  True    True      True  True    True    True     True    True
# 7  True  True    True      True  True    True    True     True    True

# %% [markdown]
# ***All values are True except values in the college column since those were NaN values***

# %% [markdown]
# **Example 3: Select Rows by Name or Index usingPandas .iloc[]**

# %%
print("original data\n", df)
# Extracting a single row by index
print("Extracting a single row by index:")
res3= df.iloc[0, :]
print(res3)
# Extracting multiple rows using a slice
print("Extracting multiple rows using a slice:")
res4= df.iloc[1:3, :]
print(res4)
# Out:
# original data
#           Name  Age  Class  fav_clr
# Row_1  Fatima   15      9    black
# Row_2     Ali   17      5   yellow
# Row_3   Hamza   19      8    green
# Row_4    Amna   20     12  magenta
# Row_5    Asim   20     12   purple
# Extracting a single row by index:
# Name       Fatima
# Age            15
# Class           9
# fav_clr     black
# Name: Row_1, dtype: object
# Extracting multiple rows using a slice:
#         Name  Age  Class fav_clr
# Row_2    Ali   17      5  yellow
# Row_3  Hamza   19      8   green

# %% [markdown]
# # 9)Column Transformation Part 1

# %%
import pandas as pd
df= pd.read_excel("C:/Users/DELL/Downloads/ESD.xlsx")
df
# Out:
#        EEID             Full Name                       Job Title  \
# 0    E02387           Emily Davis                      Sr. Manger
# 1    E04105         Theodore Dinh             Technical Architect
# 2    E02572          Luna Sanders                        Director
# 3    E02832       Penelope Jordan        Computer Systems Manager
# 4    E01639             Austin Vo                     Sr. Analyst
# 5    E00644          Joshua Gupta          Account Representative
# 6    E01550           Ruby Barnes                         Manager
# 7    E04332           Luke Martin                         Analyst
# 8    E04533         Easton Bailey                         Manager
# 9    E03838       Madeline Walker                     Sr. Analyst
# 10   E00591          Savannah Ali                      Sr. Manger
# 11   E03344         Camila Rogers               Controls Engineer
# 12   E00530             Eli Jones                         Manager
# 13   E04239          Everleigh Ng                      Sr. Manger
# 14   E03496           Robert Yang                     Sr. Analyst
# 15   E00549           Isabella Xi                  Vice President
# 16   E00163          Bella Powell                        Director
# 17   E00884          Camila Silva                      Sr. Manger
# 18   E04116          David Barnes                        Director
# 19   E04625             Adam Dang                        Director
# 20   E03680        Elias Alvarado                      Sr. Manger
# 21   E04732            Eva Rivera                        Director
# 22   E03484          Logan Rivera                        Director
# 23   E00671        Leonardo Dixon                         Analyst
# 24   E02071             Mateo Her                  Vice President
# 25   E02206        Jose Henderson                        Director
# 26   E04545         Abigail Mejia                Quality Engineer
# 27   E00154            Wyatt Chin                  Vice President
# 28   E03343             Carson Lu             Engineering Manager
# 29   E00304            Dylan Choi                  Vice President
# 30   E02594         Ezekiel Kumar                  IT Coordinator
# 31   E00402        Dominic Guzman                         Analyst
# 32   E01994          Angel Powell                      Analyst II
# 33   E03549              Mateo Vu          Account Representative
# 34   E03247      Caroline Jenkins                         Analyst
# 35   E02074            Nora Brown            Enterprise Architect
# 36   E04152         Adeline Huang               Controls Engineer
# 37   E01628         Jackson Perry                  Vice President
# 38   E04285         Riley Padilla             Technical Architect
# 39   E01417             Leah Pena            Enterprise Architect
# 40   E01754              Owen Lam            Sr. Business Partner
# 41   E03749        Kennedy Foster                         Manager
# 42   E03574            John Moore                  Vice President
# 43   E04600            William Vu          Account Representative
# 44   E00586      Sadie Washington                      Sr. Manger
# 45   E03538        Gabriel Holmes            Enterprise Architect
# 83  2020-12-21
# 84         NaT
# 85         NaT
# 86         NaT
# 87         NaT
# 88         NaT
# 89         NaT
# 90  2019-12-22
# 91         NaT
# 92         NaT
# 93         NaT
# 94         NaT
# 95         NaT
# 96         NaT
# 97         NaT
# 98         NaT
# 99         NaT
# 100        NaT
# 101        NaT
# 102        NaT
# 103        NaT
# 104 2018-10-12
# 105        NaT
# 106        NaT
# 107        NaT
# 108        NaT
# 109        NaT
# 110        NaT
# 111        NaT
# 112        NaT
# 113        NaT
# 114        NaT
# 115        NaT
# 116        NaT
# 117        NaT
# 118        NaT
# 119        NaT
# 120        NaT
# 121        NaT
# 122        NaT
# 123        NaT
# 124        NaT
# 125        NaT
# 126        NaT
# 127        NaT
# 128        NaT
# 129        NaT
# 130 2021-05-01
# 131        NaT
# 132        NaT
# 133        NaT
# 134        NaT
# 135        NaT
# 136        NaT
# 137        NaT
# 138        NaT
# 139        NaT
# 140        NaT
# 141        NaT
# 142        NaT
# 143        NaT
# 144        NaT
# 145        NaT
# 146        NaT
# 147        NaT
# 148        NaT
# 149        NaT
# 150        NaT
# 151        NaT
# 152        NaT
# 153        NaT
# 154        NaT
# 155        NaT
# 156        NaT
# 157        NaT
# 158        NaT
# 159 2013-12-13
# 160        NaT
# 161        NaT
# 162        NaT
# 163        NaT
# 164        NaT
# 165        NaT
# 166        NaT
# 167        NaT
# 168        NaT
# 169        NaT
# 170        NaT
# 171        NaT
# 172        NaT
# 173        NaT
# 174        NaT
# 175        NaT
# 176        NaT
# 177        NaT
# 178        NaT
# 179        NaT
# 180        NaT
# 181        NaT
# 182        NaT
# 183        NaT
# 184        NaT
# 185        NaT
# 186        NaT
# 187        NaT
# 188        NaT
# 189        NaT
# 190        NaT
# 191        NaT
# 192        NaT
# 193        NaT
# 194        NaT
# 195        NaT
# 196        NaT
# 197        NaT
# 198        NaT
# 199 2017-09-25
# 200        NaT
# 201        NaT
# 202        NaT
# 203        NaT
# 204        NaT
# 205        NaT
# 206        NaT
# 207        NaT
# 208        NaT
# 209        NaT
# 210        NaT
# 211        NaT
# 212        NaT
# 213        NaT
# 214        NaT
# 215        NaT
# 216        NaT
# 217        NaT
# 218        NaT
# 219        NaT
# 220        NaT
# 221        NaT
# 222        NaT
# 223        NaT
# 224        NaT
# 225        NaT
# 226        NaT
# 227 2010-01-15
# 228        NaT
# 229        NaT
# 230        NaT
# 231        NaT
# 232        NaT
# 233        NaT
# 234        NaT
# 235        NaT
# 236 2013-06-05
# 237        NaT
# 238 2020-07-17
# 239        NaT
# 240        NaT
# 241        NaT
# 242 2020-09-25
# 243        NaT
# 244        NaT
# 245        NaT
# 246        NaT
# 247        NaT
# 248        NaT
# 249        NaT
# 250        NaT
# 251        NaT
# 252        NaT
# 253        NaT
# 254        NaT
# 255        NaT
# 256        NaT
# 257        NaT
# 258        NaT
# 259        NaT
# 260        NaT
# 261        NaT
# 262 2008-06-17
# 263        NaT
# 264        NaT
# 265        NaT
# 266        NaT
# 267        NaT
# 268        NaT
# 269        NaT
# 270        NaT
# 271        NaT
# 272        NaT
# 273        NaT
# 274        NaT
# 275        NaT
# 276        NaT
# 277        NaT
# 278        NaT
# 279        NaT
# 280        NaT
# 281        NaT
# 282        NaT
# 283        NaT
# 284        NaT
# 285        NaT
# 286        NaT
# 287        NaT
# 288        NaT
# 289        NaT
# 290        NaT
# 291 2021-11-10
# 292        NaT
# 293        NaT
# 294        NaT
# 295        NaT
# 296        NaT
# 297        NaT
# 298 2020-10-03
# 299        NaT
# 300        NaT
# 301        NaT
# 302 2021-07-27
# 303        NaT
# 304        NaT
# 305        NaT
# 306        NaT
# 307        NaT
# 308        NaT
# 309        NaT
# 310        NaT
# 311        NaT
# 312        NaT
# 313        NaT
# 314        NaT
# 315        NaT
# 316        NaT
# 317        NaT
# 318        NaT
# 319        NaT
# 320 2005-04-14
# 321        NaT
# 322        NaT
# 323        NaT
# 324        NaT
# 325        NaT
# 326        NaT
# 327 2020-04-24
# 328        NaT
# 329        NaT
# 330        NaT
# 331        NaT
# 332        NaT
# 333        NaT
# 334        NaT
# 335        NaT
# 336        NaT
# 337        NaT
# 338        NaT
# 339        NaT
# 340        NaT
# 341        NaT
# 342        NaT
# 343        NaT
# 344        NaT
# 345 2016-10-03
# 346        NaT
# 347        NaT
# 348        NaT
# 349        NaT
# 350 1998-10-11
# 351        NaT
# 352        NaT
# 353        NaT
# 354        NaT
# 355        NaT
# 356        NaT
# 357        NaT
# 358        NaT
# 359        NaT
# 360        NaT
# 361        NaT
# 362        NaT
# 363        NaT
# 364        NaT
# 365        NaT
# 366        NaT
# 367        NaT
# 368        NaT
# 369        NaT
# 370        NaT
# 371        NaT
# 372        NaT
# 373        NaT
# 374        NaT
# 375        NaT
# 376 2003-01-02
# 377        NaT
# 378        NaT
# 379        NaT
# 380        NaT
# 381        NaT
# 382        NaT
# 383        NaT
# 384        NaT
# 385        NaT
# 386        NaT
# 387        NaT
# 388        NaT
# 389        NaT
# 390        NaT
# 391        NaT
# 392        NaT
# 393        NaT
# 394        NaT
# 395        NaT
# 396        NaT
# 397        NaT
# 398        NaT
# 399        NaT
# 400 2007-08-16
# 401        NaT
# 402        NaT
# 403        NaT
# 404        NaT
# 405        NaT
# 406        NaT
# 407        NaT
# 408        NaT
# 409        NaT
# 410        NaT
# 411 2019-12-11
# 412        NaT
# 413        NaT
# 414 2019-08-04
# 415        NaT
# 416        NaT
# 417        NaT
# 418        NaT
# 419        NaT
# 420        NaT
# 421        NaT
# 422        NaT
# 423        NaT
# 424        NaT
# 425        NaT
# 426        NaT
# 427        NaT
# 428        NaT
# 429        NaT
# 430 2011-12-26
# 431        NaT
# 432        NaT
# 433        NaT
# 434        NaT
# 435        NaT
# 436        NaT
# 437        NaT
# 438        NaT
# 439        NaT
# 440        NaT
# 441        NaT
# 442        NaT
# 443        NaT
# 444        NaT
# 445        NaT
# 446        NaT
# 447        NaT
# 448        NaT
# 449        NaT
# 450        NaT
# 451        NaT
# 452        NaT
# 453 2015-08-08
# 454        NaT
# 455        NaT
# 456        NaT
# 457        NaT
# 458        NaT
# 459 2020-07-12
# 460        NaT
# 461        NaT
# 462        NaT
# 463        NaT
# 464        NaT
# 465        NaT
# 466        NaT
# 467        NaT
# 468        NaT
# 469        NaT
# 470        NaT
# 471        NaT
# 472        NaT
# 473        NaT
# 474        NaT
# 475        NaT
# 476        NaT
# 477        NaT
# 478 2004-05-15
# 479        NaT
# 480        NaT
# 481        NaT
# 482        NaT
# 483        NaT
# 484        NaT
# 485        NaT
# 486        NaT
# 487 2017-08-11
# 488        NaT
# 489        NaT
# 490        NaT
# 491        NaT
# 492        NaT
# 493        NaT
# 494        NaT
# 495        NaT
# 496        NaT
# 497        NaT
# 498        NaT
# 499        NaT
# 500        NaT
# 501        NaT
# 502        NaT
# 503        NaT
# 504 2022-04-11
# 505        NaT
# 506        NaT
# 507        NaT
# 508        NaT
# 509        NaT
# 510        NaT
# 511        NaT
# 512        NaT
# 513        NaT
# 514        NaT
# 515        NaT
# 516        NaT
# 517 2015-11-30
# 518        NaT
# 519        NaT
# 520        NaT
# 521        NaT
# 522        NaT
# 523        NaT
# 524        NaT
# 525        NaT
# 526        NaT
# 527        NaT
# 528        NaT
# 529        NaT
# 530        NaT
# 531        NaT
# 532        NaT
# 533        NaT
# 534        NaT
# 535        NaT
# 536        NaT
# 537        NaT
# 538        NaT
# 539        NaT
# 540        NaT
# 541        NaT
# 542        NaT
# 543        NaT
# 544        NaT
# 545        NaT
# 546        NaT
# 547        NaT
# 548        NaT
# 549        NaT
# 550        NaT
# 551        NaT
# 552        NaT
# 553        NaT
# 554        NaT
# 555        NaT
# 556        NaT
# 557        NaT
# 558        NaT
# 559        NaT
# 560        NaT
# 561        NaT
# 562        NaT
# 563        NaT
# 564        NaT
# 565        NaT
# 566        NaT
# 567        NaT
# 568        NaT
# 569        NaT
# 570        NaT
# 571        NaT
# 572        NaT
# 573        NaT
# 574        NaT
# 575        NaT
# 576 2022-05-18
# 577        NaT
# 578        NaT
# 579        NaT
# 580        NaT
# 581        NaT
# 582        NaT
# 583        NaT
# 584        NaT
# 585        NaT
# 586        NaT
# 587        NaT
# 588        NaT
# 589        NaT
# 590 2021-05-18
# 591        NaT
# 592        NaT
# 593        NaT
# 594        NaT
# 595        NaT
# 596        NaT
# 597        NaT
# 598        NaT
# 599        NaT
# 600 2022-04-10
# 601        NaT
# 602        NaT
# 603        NaT
# 604 2021-01-07
# 605        NaT
# 606        NaT
# 607        NaT
# 608        NaT
# 609        NaT
# 610        NaT
# 611        NaT
# 612        NaT
# 613        NaT
# 614 2019-05-09
# 615        NaT
# 616        NaT
# 617        NaT
# 618        NaT
# 619 2017-09-22
# 620        NaT
# 621        NaT
# 622        NaT
# 623        NaT
# 624        NaT
# 625        NaT
# 626        NaT
# 627 2021-02-02
# 628        NaT
# 629 2015-06-09
# 630        NaT
# 631        NaT
# 632        NaT
# 633        NaT
# 634        NaT
# 635        NaT
# 636        NaT
# 637        NaT
# 638        NaT
# 639 2022-06-20
# 640        NaT
# 641        NaT
# 642        NaT
# 643        NaT
# 644 2021-03-08
# 645        NaT
# 646        NaT
# 647        NaT
# 648 1994-12-18
# 649        NaT
# 650        NaT
# 651        NaT
# 652        NaT
# 653 2021-05-01
# 654        NaT
# 655        NaT
# 656        NaT
# 657        NaT
# 658        NaT
# 659        NaT
# 660        NaT
# 661        NaT
# 662        NaT
# 663        NaT
# 664        NaT
# 665        NaT
# 666        NaT
# 667        NaT
# 668        NaT
# 669        NaT
# 670 2021-10-22
# 671        NaT
# 672        NaT
# 673        NaT
# 674        NaT
# 675 2019-04-03
# 676        NaT
# 677        NaT
# 678        NaT
# 679        NaT
# 680        NaT
# 681        NaT
# 682        NaT
# 683        NaT
# 684        NaT
# 685        NaT
# 686        NaT
# 687        NaT
# 688        NaT
# 689        NaT
# 690        NaT
# 691        NaT
# 692        NaT
# 693        NaT
# 694 2020-12-12
# 695 2022-06-03
# 696        NaT
# 697        NaT
# 698        NaT
# 699        NaT
# 700        NaT
# 701        NaT
# 702        NaT
# 703        NaT
# 704        NaT
# 705        NaT
# 706        NaT
# 707        NaT
# 708        NaT
# 709        NaT
# 710        NaT
# 711        NaT
# 712 2009-12-06
# 713        NaT
# 714        NaT
# 715 2017-12-22
# 716        NaT
# 717        NaT
# 718        NaT
# 719        NaT
# 720        NaT
# 721        NaT
# 722        NaT
# 723        NaT
# 724        NaT
# 725        NaT
# 726        NaT
# 727        NaT
# 728 2014-10-26
# 729 2018-05-09
# 730 2022-08-17
# 731        NaT
# 732        NaT
# 733        NaT
# 734        NaT
# 735        NaT
# 736        NaT
# 737 2021-05-24
# 738 2020-06-09
# 739        NaT
# 740        NaT
# 741        NaT
# 742 2007-04-08
# 743        NaT
# 744 2020-07-17
# 745        NaT
# 746        NaT
# 747 2006-04-22
# 748 2008-05-30
# 749        NaT
# 750 2022-04-20
# 751        NaT
# 752        NaT
# 753        NaT
# 754        NaT
# 755        NaT
# 756        NaT
# 757        NaT
# 758        NaT
# 759        NaT
# 760        NaT
# 761        NaT
# 762        NaT
# 763        NaT
# 764        NaT
# 765        NaT
# 766        NaT
# 767        NaT
# 768        NaT
# 769        NaT
# 770        NaT
# 771        NaT
# 772        NaT
# 773        NaT
# 774        NaT
# 775        NaT
# 776        NaT
# 777        NaT
# 778 2021-04-20
# 779 2014-12-25
# 780        NaT
# 781        NaT
# 782        NaT
# 783 2021-07-09
# 784        NaT
# 785        NaT
# 786        NaT
# 787        NaT
# 788        NaT
# 789        NaT
# 790        NaT
# 791        NaT
# 792        NaT
# 793        NaT
# 794        NaT
# 795        NaT
# 796        NaT
# 797        NaT
# 798        NaT
# 799        NaT
# 800        NaT
# 801        NaT
# 802        NaT
# 803        NaT
# 804        NaT
# 805        NaT
# 806        NaT
# 807        NaT
# 808        NaT
# 809        NaT
# 810        NaT
# 811 2017-12-09
# 812        NaT
# 813        NaT
# 814        NaT
# 815        NaT
# 816        NaT
# 817        NaT
# 818        NaT
# 819        NaT
# 820        NaT
# 821        NaT
# 822        NaT
# 823        NaT
# 824        NaT
# 825        NaT
# 826        NaT
# 827 2016-03-16
# 828        NaT
# 829        NaT
# 830        NaT
# 831        NaT
# 832        NaT
# 833        NaT
# 834 1996-12-14
# 835        NaT
# 836        NaT
# 837        NaT
# 838        NaT
# 839        NaT
# 840        NaT
# 841        NaT
# 842        NaT
# 843        NaT
# 844        NaT
# 845        NaT
# 846 2019-05-23
# 847        NaT
# 848        NaT
# 849        NaT
# 850        NaT
# 851        NaT
# 852        NaT
# 853        NaT
# 854        NaT
# 855        NaT
# 856        NaT
# 857        NaT
# 858        NaT
# 859        NaT
# 860        NaT
# 861        NaT
# 862        NaT
# 863        NaT
# 864        NaT
# 865        NaT
# 866        NaT
# 867        NaT
# 868 2021-04-09
# 869        NaT
# 870        NaT
# 871        NaT
# 872        NaT
# 873        NaT
# 874        NaT
# 875        NaT
# 876        NaT
# 877        NaT
# 878        NaT
# 879        NaT
# 880        NaT
# 881        NaT
# 882        NaT
# 883        NaT
# 884        NaT
# 885        NaT
# 886        NaT
# 887        NaT
# 888        NaT
# 889        NaT
# 890 2020-02-04
# 891        NaT
# 892        NaT
# 893        NaT
# 894        NaT
# 895 2018-05-31
# 896        NaT
# 897        NaT
# 898        NaT
# 899        NaT
# 900        NaT
# 901        NaT
# 902        NaT
# 903        NaT
# 904        NaT
# 905 2021-08-14
# 906        NaT
# 907        NaT
# 908 2021-01-15
# 909        NaT
# 910        NaT
# 911        NaT
# 912        NaT
# 913        NaT
# 914        NaT
# 915        NaT
# 916        NaT
# 917        NaT
# 918        NaT
# 919        NaT
# 920        NaT
# 921        NaT
# 922        NaT
# 923        NaT
# 924        NaT
# 925        NaT
# 926        NaT
# 927        NaT
# 928        NaT
# 929        NaT
# 930        NaT
# 931        NaT
# 932        NaT
# 933        NaT
# 934        NaT
# 935        NaT
# 936        NaT
# 937        NaT
# 938        NaT
# 939        NaT
# 940        NaT
# 941        NaT
# 942        NaT
# 943        NaT
# 944        NaT
# 945        NaT
# 946        NaT
# 947        NaT
# 948        NaT
# 949        NaT
# 950        NaT
# 951        NaT
# 952        NaT
# 953        NaT
# 954        NaT
# 955        NaT
# 956        NaT
# 957 2004-05-24
# 958        NaT
# 959        NaT
# 960        NaT
# 961        NaT
# 962        NaT
# 963 2021-03-02
# 964        NaT
# 965        NaT
# 966        NaT
# 967        NaT
# 968        NaT
# 969        NaT
# 970        NaT
# 971        NaT
# 972        NaT
# 973        NaT
# 974        NaT
# 975        NaT
# 976        NaT
# 977        NaT
# 978        NaT
# 979        NaT
# 980        NaT
# 981        NaT
# 982 2017-03-26
# 983 2019-03-14
# 984        NaT
# 985        NaT
# 986        NaT
# 987        NaT
# 988        NaT
# 989        NaT
# 990        NaT
# 991 2004-11-27
# 992        NaT
# 993        NaT
# 994        NaT
# 995        NaT
# 996 2018-01-08
# 997        NaT
# 998        NaT
# 999        NaT

# %% [markdown]
# ***Now we will check how many employees get bonus and how many of them don't and store this info in new column "GetBonus"***

# %%
df.loc[(df["Bonus %"]==0), "GetBonus"]= "no bonus"
df.loc[(df["Bonus %"]>0), "GetBonus"]="bonus"
df.head(10)
# Out:
#      EEID        Full Name                 Job Title  Department  \
# 0  E02387      Emily Davis                Sr. Manger          IT
# 1  E04105    Theodore Dinh       Technical Architect          IT
# 2  E02572     Luna Sanders                  Director     Finance
# 3  E02832  Penelope Jordan  Computer Systems Manager          IT
# 4  E01639        Austin Vo               Sr. Analyst     Finance
# 5  E00644     Joshua Gupta    Account Representative       Sales
# 6  E01550      Ruby Barnes                   Manager          IT
# 7  E04332      Luke Martin                   Analyst     Finance
# 8  E04533    Easton Bailey                   Manager  Accounting
# 9  E03838  Madeline Walker               Sr. Analyst     Finance
#
#             Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0  Research & Development  Female      Black   55 2016-04-08         141604
# 1           Manufacturing    Male      Asian   59 1997-11-29          99975
# 2     Speciality Products  Female  Caucasian   50 2006-10-26         163099
# 3           Manufacturing  Female  Caucasian   26 2019-09-27          84913
# 4           Manufacturing    Male      Asian   55 1995-11-20          95409
# 5               Corporate    Male      Asian   57 2017-01-24          50994
# 6               Corporate  Female  Caucasian   27 2020-07-01         119746
# 7           Manufacturing    Male      Black   25 2020-05-16          41336
# 8           Manufacturing    Male  Caucasian   29 2019-01-25         113527
# 9     Speciality Products  Female  Caucasian   34 2018-06-13          77203
#
#    Bonus %        Country       City  Exit Date  GetBonus
# 0     0.15  United States    Seattle 2021-10-16     bonus
# 1     0.00          China  Chongqing        NaT  no bonus
# 2     0.20  United States    Chicago        NaT     bonus
# 3     0.07  United States    Chicago        NaT     bonus
# 4     0.00  United States    Phoenix        NaT  no bonus
# 5     0.00          China  Chongqing        NaT  no bonus
# 6     0.10  United States    Phoenix        NaT     bonus
# 7     0.00  United States      Miami 2021-05-20  no bonus
# 8     0.06  United States     Austin        NaT     bonus
# 9     0.00  United States    Chicago        NaT  no bonus

# %% [markdown]
# ***Combining 2 or more columns using + operator***

# %%
import pandas as pd
data= pd.read_csv("C:/Users/DELL/Desktop/jupyter projects/practice.csv")
data
# Out:
#    RollNum First Name Last Name   Salary City    Hobby
# 0      236   rubaisha     munir  1527139  BWP  Singing
# 1      240    malaika    arshad  2000000  JHL  Dancing
# 2      251     ayesha    nadeem    98777  SWL  Reading
# 3      243     fariha     mehdi  1345680  SWL   Baking
# 4      234     maryam      khan  1457729  KRC  Reading

# %%
data["Full Name"]= data["First Name"].str.capitalize() + " " + data["Last Name"].str.capitalize()
data
# Out:
#    RollNum First Name Last Name   Salary City    Hobby       Full Name
# 0      236   rubaisha     munir  1527139  BWP  Singing  Rubaisha Munir
# 1      240    malaika    arshad  2000000  JHL  Dancing  Malaika Arshad
# 2      251     ayesha    nadeem    98777  SWL  Reading   Ayesha Nadeem
# 3      243     fariha     mehdi  1345680  SWL   Baking    Fariha Mehdi
# 4      234     maryam      khan  1457729  KRC  Reading     Maryam Khan

# %% [markdown]
# # 10) Column Transformation Part2

# %%
import pandas as pd
data= pd.read_csv("C:/Users/DELL/Desktop/jupyter projects/practice.csv")
print(data)
# Out:
#    RollNum First Name Last Name   Salary City    Hobby
# 0      236   rubaisha     munir  1527139  BWP  Singing
# 1      240    malaika    arshad  2000000  JHL  Dancing
# 2      251     ayesha    nadeem    98777  SWL  Reading
# 3      243     fariha     mehdi  1345680  SWL   Baking
# 4      234     maryam      khan  1457729  KRC  Reading

# %% [markdown]
# - **create a new column Bonus that stores 20% of salaries i.e. operation on existing column salary for new column Bonus**

# %%
data["Bonus"]= (data["Salary"]/100) * 20
print(data)
# Out:
#    RollNum First Name Last Name   Salary City    Hobby     Bonus
# 0      236   rubaisha     munir  1527139  BWP  Singing  305427.8
# 1      240    malaika    arshad  2000000  JHL  Dancing  400000.0
# 2      251     ayesha    nadeem    98777  SWL  Reading   19755.4
# 3      243     fariha     mehdi  1345680  SWL   Baking  269136.0
# 4      234     maryam      khan  1457729  KRC  Reading  291545.8

# %%
import pandas as pd
data={"Month":["January", "February","March","April"]}
a= pd.DataFrame(data)
print(a)
# Out:
#       Month
# 0   January
# 1  February
# 2     March
# 3     April

# %% [markdown]
# - **Create a new column through map() that stores first 3 letters of each value in column 'Month'**

# %%
def extract(value):
    return value[0:3]
a["Short_Month"]= a["Month"].map(extract)
print(a)
# Out:
#       Month Short_Month
# 0   January         Jan
# 1  February         Feb
# 2     March         Mar
# 3     April         Apr

# %% [markdown]
# # 11)GroupBy:
# - The groupby() method allows you to group your data and execute functions on these groups.
# - it is used to summarize a large dataset.

# %%
import pandas as pd
data= pd.read_excel("C:/Users/DELL/Downloads/ESD.xlsx")
print(data.head(10))
# Out:
#      EEID        Full Name                 Job Title  Department  \
# 0  E02387      Emily Davis                Sr. Manger          IT
# 1  E04105    Theodore Dinh       Technical Architect          IT
# 2  E02572     Luna Sanders                  Director     Finance
# 3  E02832  Penelope Jordan  Computer Systems Manager          IT
# 4  E01639        Austin Vo               Sr. Analyst     Finance
# 5  E00644     Joshua Gupta    Account Representative       Sales
# 6  E01550      Ruby Barnes                   Manager          IT
# 7  E04332      Luke Martin                   Analyst     Finance
# 8  E04533    Easton Bailey                   Manager  Accounting
# 9  E03838  Madeline Walker               Sr. Analyst     Finance
#
#             Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0  Research & Development  Female      Black   55 2016-04-08         141604
# 1           Manufacturing    Male      Asian   59 1997-11-29          99975
# 2     Speciality Products  Female  Caucasian   50 2006-10-26         163099
# 3           Manufacturing  Female  Caucasian   26 2019-09-27          84913
# 4           Manufacturing    Male      Asian   55 1995-11-20          95409
# 5               Corporate    Male      Asian   57 2017-01-24          50994
# 6               Corporate  Female  Caucasian   27 2020-07-01         119746
# 7           Manufacturing    Male      Black   25 2020-05-16          41336
# 8           Manufacturing    Male  Caucasian   29 2019-01-25         113527
# 9     Speciality Products  Female  Caucasian   34 2018-06-13          77203
#
#    Bonus %        Country       City  Exit Date
# 0     0.15  United States    Seattle 2021-10-16
# 1     0.00          China  Chongqing        NaT
# 2     0.20  United States    Chicago        NaT
# 3     0.07  United States    Chicago        NaT
# 4     0.00  United States    Phoenix        NaT
# 5     0.00          China  Chongqing        NaT
# 6     0.10  United States    Phoenix        NaT
# 7     0.00  United States      Miami 2021-05-20
# 8     0.06  United States     Austin        NaT
# 9     0.00  United States    Chicago        NaT

# %% [markdown]
# **Find Departmentwise Gender count**

# %%
gp= data.groupby("Department").agg({"Gender":"count"})
print(gp)
# Out:
#                  Gender
# Department
# Accounting           96
# Engineering         158
# Finance             120
# Human Resources     125
# IT                  241
# Marketing           120
# Sales               140

# %% [markdown]
# **Find the count of Male and Female of each Department using EEID**

# %%
gp1= data.groupby(["Department", "Gender"]).agg({"EEID":"count"}) #2 levels of groupby i.e. 1st on department & 2nd on gender basis
print(gp1)
# Out:
#                         EEID
# Department      Gender
# Accounting      Female    53
#                 Male      43
# Engineering     Female    80
#                 Male      78
# Finance         Female    69
#                 Male      51
# Human Resources Female    64
#                 Male      61
# IT              Female   119
#                 Male     122
# Marketing       Female    57
#                 Male      63
# Sales           Female    76
#                 Male      64

# %% [markdown]
# **Find mean age of each country**

# %%
gp2= data.groupby("Country").agg({"Age":"mean"})
print(gp2)
# Out:
#                      Age
# Country
# Brazil         43.654676
# China          45.389908
# United States  44.197512

# %% [markdown]
# **Find average annual salary of each country**

# %%
gp3= data.groupby("Country").agg({"Annual Salary":"mean"})
print(gp3)
# Out:
#                Annual Salary
# Country
# Brazil         112324.834532
# China          113823.532110
# United States  113204.794712

# %% [markdown]
# **Find maximum annual salary of each country**

# %%
gp4= data.groupby("Country").agg({"Annual Salary":"max"})
print(gp4)
# Out:
#                Annual Salary
# Country
# Brazil                258426
# China                 257194
# United States         258498

# %% [markdown]
# **Find maximum annual salary of each country on the basis of gender**

# %%
gp5=data.groupby(["Country","Gender"]).agg({"Annual Salary":"max"})
print(gp5)
# Out:
#                       Annual Salary
# Country       Gender
# Brazil        Female         258426
#               Male           249506
# China         Female         249686
#               Male           257194
# United States Female         258498
#               Male           258081

# %% [markdown]
# ## Conclusion
# using groupby we can create summary of data and then perform various operations on that data using agg() to find most accurate and precise results which we cant conclude from entire original dataset

# %% [markdown]
# # 12) Merge, Concatenate & Join dataframes
# - Merging, joining, and concatenating DataFrames in pandas are important techniques that allow you to combine multiple datasets into one.
# - These techniques are essential for cleaning, transforming, and analyzing data.
# - Merging, joining, and concatenating are often used interchangeably, but they refer to different methods of combining data.

# %% [markdown]
# ## i) Merging DataFrames:
# - Merging is the process of combining two or more DataFrames into a single DataFrame by linking rows based on one or more common keys.
# - The common keys can be one or more columns that have matching values in the DataFrames being merged.
# ### Different Types of Merges
# There are four types of merges in pandas: inner, outer, left, and right.
# - **Inner Merge:** Returns only the rows that have matching values in both DataFrames.
# - **Outer Merge:** Returns all the rows from both DataFrames and fills in the missing values with NaN where there is no match.
# - **Left Merge:** Returns all the rows from the left DataFrame and the matching rows from the right DataFrame. Fills in the missing values with NaN where there is no match.
# - **Right Merge:** Returns all the rows from the right DataFrame and the matching rows from the left DataFrame. Fills in the missing values with NaN where there is no match.
# #### Examples of How to Perform Different Types of Merges
# Let's look at some examples of how to perform different types of merges using Pandas.
# - ***Example 1: Inner Merge***

# %%
import pandas as pd

df1 = pd.DataFrame({"Key":['A','B','C','D'], "Value":[1,2,3,4]})
print("1st DataFrame:\n ", df1)
df2= pd.DataFrame({"Key":['B','D','E','F'], "Vlaue":[5,6,7,8]})
print("2nd DataFrame:\n ", df2)
#inner merge
inner_merge= pd.merge(df1, df2, on= "Key") #merge is by default set to inner merge
print(inner_merge)
# Out:
# 1st DataFrame:
#     Key  Value
# 0   A      1
# 1   B      2
# 2   C      3
# 3   D      4
# 2nd DataFrame:
#     Key  Vlaue
# 0   B      5
# 1   D      6
# 2   E      7
# 3   F      8
#   Key  Value  Vlaue
# 0   B      2      5
# 1   D      4      6

# %% [markdown]
# - ***Example 2: Outer Merge***

# %%
outer_merge=pd.merge(df1,df2, on="Key", how='outer')
print(outer_merge)
# Out:
#   Key  Value  Vlaue
# 0   A    1.0    NaN
# 1   B    2.0    5.0
# 2   C    3.0    NaN
# 3   D    4.0    6.0
# 4   E    NaN    7.0
# 5   F    NaN    8.0

# %% [markdown]
# - ***Example 3: Left Merge***

# %%
df3 = pd.DataFrame({'Key': ['B', 'D', 'E'], 'value': [5, 6, 7]})
left_merge=pd.merge(df1,df3,on='Key', how='left')
print(left_merge)
# Out:
#   Key  Value  value
# 0   A      1    NaN
# 1   B      2    5.0
# 2   C      3    NaN
# 3   D      4    6.0

# %% [markdown]
# - ***Example 4: Right Merge***

# %%
right_merge=pd.merge(df1,df3, on='Key', how='right')
print(right_merge)
# Out:
#   Key  Value  value
# 0   B    2.0      5
# 1   D    4.0      6
# 2   E    NaN      7

# %% [markdown]
# ## ii)Joining DataFrames
# - Joining is a method of combining two DataFrames into one based on their index or column values.
# - There are four **types** of joins in pandas: inner, outer, left, and right.
# - **Inner Join:** Returns only the rows that have matching index or column values in both DataFrames
# - **Outer Join:** Returns all the rows from both DataFrames and fills in the missing values with NaN where there is no match.
# - **Left Join:** Returns all the rows from the left DataFrame and the matching rows from the right DataFrame. Fills in the missing values with NaN where there is no match.
# - **Right Join:** Returns all the rows from the right DataFrame and the matching rows from the left DataFrame. Fills in the missing values with NaN where there is no match.

# %% [markdown]
# - ***Example 1: Inner Join***

# %%
data1 = {'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'], 
        'Age':[27, 24, 22, 32]} 
data2 = {'Address':['Allahabad', 'Kannuaj', 'Allahabad', 'Kannuaj'], 
        'Qualification':['MCA', 'Phd', 'Bcom', 'B.hons']} 
df1 = pd.DataFrame(data1,index=['K0', 'K1', 'K2', 'K3'])
df2 = pd.DataFrame(data2, index=['K0', 'K2', 'K3', 'K4'])
print(df1, "\n\n", df2) 
inner_join= df1.join(df2, how='inner')
print(inner_join)
# Out:
#       Name  Age
# K0     Jai   27
# K1  Princi   24
# K2  Gaurav   22
# K3    Anuj   32
#
#        Address Qualification
# K0  Allahabad           MCA
# K2    Kannuaj           Phd
# K3  Allahabad          Bcom
# K4    Kannuaj        B.hons
#       Name  Age    Address Qualification
# K0     Jai   27  Allahabad           MCA
# K2  Gaurav   22    Kannuaj           Phd
# K3    Anuj   32  Allahabad          Bcom

# %% [markdown]
# - ***Example 2: Outer join***

# %%
outer_join=df1.join(df2, how='outer')
print(outer_join)
# Out:
#       Name   Age    Address Qualification
# K0     Jai  27.0  Allahabad           MCA
# K1  Princi  24.0        NaN           NaN
# K2  Gaurav  22.0    Kannuaj           Phd
# K3    Anuj  32.0  Allahabad          Bcom
# K4     NaN   NaN    Kannuaj        B.hons

# %% [markdown]
# - ***Example 3: Left join***

# %%
left_join=df1.join(df2, how="left")
print(left_join)
# Out:
#       Name  Age    Address Qualification
# K0     Jai   27  Allahabad           MCA
# K1  Princi   24        NaN           NaN
# K2  Gaurav   22    Kannuaj           Phd
# K3    Anuj   32  Allahabad          Bcom

# %% [markdown]
# - ***Example 4: Right join***

# %%
right_join=df1.join(df2, how="right")
print(right_join)
# Out:
#       Name   Age    Address Qualification
# K0     Jai  27.0  Allahabad           MCA
# K2  Gaurav  22.0    Kannuaj           Phd
# K3    Anuj  32.0  Allahabad          Bcom
# K4     NaN   NaN    Kannuaj        B.hons

# %% [markdown]
# ## iii)Concatenating Dtaframes
# - Concatenating is the process of joining two or more DataFrames either vertically or horizontally.
# - In pandas, this can be achieved using the concat() function. The concat() function allows you to combine two or more DataFrames into a single DataFrame by stacking them either vertically or horizontally.
# - **Examples** of how to concatenate two or more DataFrames using pandas
# To concatenate two or more DataFrames ***vertically***, you can use the following code:

# %%
import pandas as pd

df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                    'B': ['B0', 'B1', 'B2', 'B3'],
                    'C': ['C0', 'C1', 'C2', 'C3'],
                    'D': ['D0', 'D1', 'D2', 'D3']})
 
df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                    'B': ['B4', 'B5', 'B6', 'B7'],
                    'C': ['C4', 'C5', 'C6', 'C7'],
                    'D': ['D4', 'D5', 'D6', 'D7']})
vertical_concat= pd.concat([df1,df2])
print(vertical_concat)
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3
# 0  A4  B4  C4  D4
# 1  A5  B5  C5  D5
# 2  A6  B6  C6  D6
# 3  A7  B7  C7  D7

# %% [markdown]
# - To concatenate two or more DataFrames ***horizontally***, you can use the following code:

# %%
horizontal_concat=pd.concat([df1,df2], axis=1)
print(horizontal_concat)
# Out:
#     A   B   C   D   A   B   C   D
# 0  A0  B0  C0  D0  A4  B4  C4  D4
# 1  A1  B1  C1  D1  A5  B5  C5  D5
# 2  A2  B2  C2  D2  A6  B6  C6  D6
# 3  A3  B3  C3  D3  A7  B7  C7  D7

# %% [markdown]
# ## Conclusion:
# The main difference between join vs merge would be;
# - **join()** is used to combine two DataFrames on the index but not on columns whereas,
# - **merge()** is primarily used to specify the columns you want to join on, this also supports joining on indexes and combination of index and columns.
# - **concat()** is used for concatenating data frames either vertically or horizontally.

# %%
import pandas as pd

# create two dataframes with different shapes and column names
df1 = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6], 'C': [7, 8, 9]})
df2 = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 7], 'C': [10, 11, 12]})

print(df1)
print(df2)

# compare dataframes
diff = df1.compare(df2)

# print differences
print(diff)
# Out:
#    A  B  C
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9
#    A  B   C
# 0  1  4  10
# 1  2  5  11
# 2  3  7  12
#      B          C
#   self other self other
# 0  NaN   NaN    7    10
# 1  NaN   NaN    8    11
# 2  6.0   7.0    9    12

# %% [markdown]
# # 13)Comparing DataFrames
# - The compare method in pandas shows the differences between two DataFrames.
# - It compares two data frames, row-wise and column-wise, and presents the differences side by side.
# - The compare method can only compare DataFrames of the same shape, with exact dimensions and identical row and column labels.
# ## Syntax
# DataFrame.compare(other, align_axis=1, keep_shape=False, keep_equal=False)
# ## Parameters
# The compare method accepts the following parameters:
# - **other:** This is the DataFrame for comparison.
# - **align_axis:** This indicates the axis of comparison, with 0 for rows, and 1, the default value, for columns.
# - **keep_shape:** This is a boolean parameter. Setting this to True prevents dropping of any row or column, and compare drops rows and columns with all elements same for the two data frames for the default value False.
# - **keep_equal:** This is another boolean parameter. Setting this to True shows equal values between the two DataFrames, while compare shows the positions with the same values for the two data frames as NaN for the default value False.

# %%
import pandas as pd
print("-----1st DataFrame-----")
df1= pd.DataFrame({'Name':['Ali','Amna','Bisma','Hadi'],'CGPA':[3.51,3.05,2.60,3.00],'Age':[17,18,19,19]})
print(df1)
print("-----2nd DataFrame-----")
df2= pd.DataFrame({'Name':['Ali','Ayesha','Ahmad','Hadi'], 'CGPA':[3.11,3.90,4.00,3.00],'Age':[18,18,20,19]})
print(df2)
comp1= df1.compare(df2)
print("----Comapring 2 DataFrames using only 'other' parameter-----")
print(comp1)
print("-----Comapring 2 DataFrames using 'other' and 'keep_equal' parameter-----")
comp2= df1.compare(df2, keep_equal=True)
print(comp2)
print("-----Comapring 2 DataFrames using 'other' and 'keep_shape' parameter-----")
comp3=df1.compare(df2, keep_shape=True)
print(comp3)
print("-----Comapring 2 DataFrames using 'other', 'keep_equal' and 'keep_shape' parameter-----")
comp4=df1.compare(df2,keep_equal=True, keep_shape=True) #by default align_axis=1
print(comp4)
print("-----Comapring 2 DataFrames using 'other' and 'align_axis' parameter-----")
comp5=df1.compare(df2, align_axis=0)
print(comp5)
print("-----Comapring 2 DataFrames using 'other','keep_equal','keep_shape' and 'align_axis' parameter-----")
comp6=df1.compare(df2, keep_equal=True, keep_shape=True, align_axis=0)
print(comp6)
# Out:
# -----1st DataFrame-----
#     Name  CGPA  Age
# 0    Ali  3.51   17
# 1   Amna  3.05   18
# 2  Bisma  2.60   19
# 3   Hadi  3.00   19
# -----2nd DataFrame-----
#      Name  CGPA  Age
# 0     Ali  3.11   18
# 1  Ayesha  3.90   18
# 2   Ahmad  4.00   20
# 3    Hadi  3.00   19
# ----Comapring 2 DataFrames using only 'other' parameter-----
#     Name          CGPA         Age
#     self   other  self other  self other
# 0    NaN     NaN  3.51  3.11  17.0  18.0
# 1   Amna  Ayesha  3.05  3.90   NaN   NaN
# 2  Bisma   Ahmad  2.60  4.00  19.0  20.0
# -----Comapring 2 DataFrames using 'other' and 'keep_equal' parameter-----
#     Name          CGPA        Age
#     self   other  self other self other
# 0    Ali     Ali  3.51  3.11   17    18
# 1   Amna  Ayesha  3.05  3.90   18    18
# 2  Bisma   Ahmad  2.60  4.00   19    20
# -----Comapring 2 DataFrames using 'other' and 'keep_shape' parameter-----
#     Name          CGPA         Age
#     self   other  self other  self other
# 0    NaN     NaN  3.51  3.11  17.0  18.0
# 1   Amna  Ayesha  3.05  3.90   NaN   NaN
# 2  Bisma   Ahmad  2.60  4.00  19.0  20.0
# 3    NaN     NaN   NaN   NaN   NaN   NaN
# -----Comapring 2 DataFrames using 'other', 'keep_equal' and 'keep_shape' parameter-----
#     Name          CGPA        Age
#     self   other  self other self other
# 0    Ali     Ali  3.51  3.11   17    18
# 1   Amna  Ayesha  3.05  3.90   18    18
# 2  Bisma   Ahmad  2.60  4.00   19    20
# 3   Hadi    Hadi  3.00  3.00   19    19
# -----Comapring 2 DataFrames using 'other' and 'align_axis' parameter-----
#            Name  CGPA   Age
# 0 self      NaN  3.51  17.0
#   other     NaN  3.11  18.0
# 1 self     Amna  3.05   NaN
#   other  Ayesha  3.90   NaN
# 2 self    Bisma  2.60  19.0
#   other   Ahmad  4.00  20.0
# -----Comapring 2 DataFrames using 'other','keep_equal','keep_shape' and 'align_axis' parameter-----
#            Name  CGPA  Age
# 0 self      Ali  3.51   17
#   other     Ali  3.11   18
# 1 self     Amna  3.05   18
#   other  Ayesha  3.90   18
# 2 self    Bisma  2.60   19
#   other   Ahmad  4.00   20
# 3 self     Hadi  3.00   19
#   other    Hadi  3.00   19

# %% [markdown]
# ## Conclusion
# we use .compare() to find the difference between 2 dataframes by comparing them. For example, 1st dataframe is of year 2022 and other one is of 2023 we want to compare them to see differences made in one year

# %% [markdown]
# # 14) Pivoting & Melting DataFrames
# ## i) Pivoting
# ### ***Pandas.pivot()***
# - pivot() allows you to transform or reshape data
# - pandas.pivot(index, columns, values) function produces a pivot table based on 3 columns of the DataFrame.Uses unique values from the index/columns and fills them with values.
# - **Syntax:** pandas.pivot(index, columns, values)
# - **Parameters:**
#
# **index[ndarray] :** Labels to use to make new frame’s index
#
# **columns[ndarray] :** Labels to use to make new frame’s columns
#
# **values[ndarray] :** Values to use for populating new frame’s values
#
# - **Returns:** Reshaped DataFrame
# - **Exception:** ValueError raised if there are any duplicates.
# #### Creating a Sample DataFrame:

# %%
import pandas as pd
df= pd.DataFrame({"Rollnum":[229,236,240,243,251],"Name":["Malaika Mehmood", "Rubaisha Munir", "Malaika Arshad", "Fariha Mehdi","Ayesha Nadeem"],"CGPA":[3.5,3.5,3.7,3.1,3.2],"Age":[21,20,21,22,21]})
print(df)
# Out:
#    Rollnum             Name  CGPA  Age
# 0      229  Malaika Mehmood   3.5   21
# 1      236   Rubaisha Munir   3.5   20
# 2      240   Malaika Arshad   3.7   21
# 3      243     Fariha Mehdi   3.1   22
# 4      251    Ayesha Nadeem   3.2   21

# %% [markdown]
# #### Pandas pivot() Function Examples
# Below are some examples by which we can pivot a DataFrame using Pandas pivot() function in Python:
# - **Creating and Pivot a DataFrame:**

# %%
print("taking only cgpa as value")
p2= df.pivot(index='Rollnum',columns='Name', values='CGPA')
print(p2)
print("taking only age as value")
p3=df.pivot(index="Rollnum",columns="Name",values="Age")
print(p3)
# Out:
# taking only cgpa as value
# Name     Ayesha Nadeem  Fariha Mehdi  Malaika Arshad  Malaika Mehmood  \
# Rollnum
# 229                NaN           NaN             NaN              3.5
# 236                NaN           NaN             NaN              NaN
# 240                NaN           NaN             3.7              NaN
# 243                NaN           3.1             NaN              NaN
# 251                3.2           NaN             NaN              NaN
#
# Name     Rubaisha Munir
# Rollnum
# 229                 NaN
# 236                 3.5
# 240                 NaN
# 243                 NaN
# 251                 NaN
# taking only age as value
# Name     Ayesha Nadeem  Fariha Mehdi  Malaika Arshad  Malaika Mehmood  \
# Rollnum
# 229                NaN           NaN             NaN             21.0
# 236                NaN           NaN             NaN              NaN
# 240                NaN           NaN            21.0              NaN
# 243                NaN          22.0             NaN              NaN
# 251               21.0           NaN             NaN              NaN
#
# Name     Rubaisha Munir
# Rollnum
# 229                 NaN
# 236                20.0
# 240                 NaN
# 243                 NaN
# 251                 NaN

# %% [markdown]
# - **Creating a Multi-level Pivot Table with Pandas DataFrame**

# %%
p1= df.pivot(index="Rollnum",columns="Name")
print(p1)
#it can also be done as
print("ANOTHER WAY")
p4= df.pivot(index="Rollnum", columns="Name", values=["Age","CGPA"])
print(p4)
# Out:
#                  CGPA                                              \
# Name    Ayesha Nadeem Fariha Mehdi Malaika Arshad Malaika Mehmood
# Rollnum
# 229               NaN          NaN            NaN             3.5
# 236               NaN          NaN            NaN             NaN
# 240               NaN          NaN            3.7             NaN
# 243               NaN          3.1            NaN             NaN
# 251               3.2          NaN            NaN             NaN
#
#                                  Age                              \
# Name    Rubaisha Munir Ayesha Nadeem Fariha Mehdi Malaika Arshad
# Rollnum
# 229                NaN           NaN          NaN            NaN
# 236                3.5           NaN          NaN            NaN
# 240                NaN           NaN          NaN           21.0
# 243                NaN           NaN         22.0            NaN
# 251                NaN          21.0          NaN            NaN
#
#
# Name    Malaika Mehmood Rubaisha Munir
# Rollnum
# 229                21.0            NaN
# 236                 NaN           20.0
# 240                 NaN            NaN
# 243                 NaN            NaN
# 251                 NaN            NaN
# ANOTHER WAY
#                   Age                                              \
# Name    Ayesha Nadeem Fariha Mehdi Malaika Arshad Malaika Mehmood
# Rollnum
# 229               NaN          NaN            NaN            21.0
# 236               NaN          NaN            NaN             NaN
# 240               NaN          NaN           21.0             NaN
# 243               NaN         22.0            NaN             NaN
# 251              21.0          NaN            NaN             NaN
#
#                                 CGPA                              \
# Name    Rubaisha Munir Ayesha Nadeem Fariha Mehdi Malaika Arshad
# Rollnum
# 229                NaN           NaN          NaN            NaN
# 236               20.0           NaN          NaN            NaN
# 240                NaN           NaN          NaN            3.7
# 243                NaN           NaN          3.1            NaN
# 251                NaN           3.2          NaN            NaN
#
#
# Name    Malaika Mehmood Rubaisha Munir
# Rollnum
# 229                 3.5            NaN
# 236                 NaN            3.5
# 240                 NaN            NaN
# 243                 NaN            NaN
# 251                 NaN            NaN

# %% [markdown]
# - **ValueError Raised in Pivoting a DataFrame**
#
# Raise ValueError when there are any index, columns combinations with multiple values.

# %%
import pandas as pd
df= pd.DataFrame({"Rollnum":[229,229,240,243,251],"Name":["Malaika Mehmood", "Malaika Mehmood", "Malaika Arshad", "Fariha Mehdi","Ayesha Nadeem"],"CGPA":[3.5,3.5,3.7,3.1,3.2],"Age":[21,20,21,22,21]})
print(df)
# Out:
#    Rollnum             Name  CGPA  Age
# 0      229  Malaika Mehmood   3.5   21
# 1      229  Malaika Mehmood   3.5   20
# 2      240   Malaika Arshad   3.7   21
# 3      243     Fariha Mehdi   3.1   22
# 4      251    Ayesha Nadeem   3.2   21

# %%
#p5= df.pivot(index="Rollnum",columns="Name",values="Age")
#print(p5)

# %% [markdown]
# ### ***Pandas.pivot_table()***
# - Pivot table is used to summarize and aggregate data inside dataframe
# - create a spreadsheet-style pivot table as a DataFrame.
# - Levels in the pivot table will be stored in MultiIndex objects (hierarchical indexes) on the index and columns of the result DataFrame.
# - **Syntax:** pandas.pivot_table(data, values=None, index=None, columns=None, aggfunc=’mean’, fill_value=None, margins=False, dropna=True, margins_name=’All’)
# - **Parameters:**
#
# **data :** DataFrame
#
# **values :** column to aggregate, optional
#
# **index:** column, Grouper, array, or list of the previous
#
# **columns:** column, Grouper, array, or list of the previous
#
# **aggfunc:** function, list of functions, dict, default numpy.mean
#
# **->** If list of functions passed, the resulting pivot table will have hierarchical columns whose top level are the function names.
#
# **->** If dict is passed, the key is column to aggregate and value is function or list of functions
#
# **fill_value[scalar, default None] :** Value to replace missing values with
#
# **margins[boolean, default False] :** Add all row / columns (e.g. for subtotal / grand totals)
#
# **dropna[boolean, default True] :** Do not include columns whose entries are all NaN
#
# **margins_name[string, default ‘All’] :** Name of the row / column that will contain the totals when margins is True.
#
#
# - **Returns:** DataFrame

# %% [markdown]
# - **Create a simple dataframe**

# %%
import pandas as pd
df= pd.read_csv("C:/Users/DELL/Downloads/weather2.csv")
print(df)
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/1/2017  new york           61        54
# 2  5/2/2017  new york           70        60
# 3  5/2/2017  new york           72        62
# 4  5/1/2017    mumbai           75        80
# 5  5/1/2017    mumbai           78        83
# 6  5/2/2017    mumbai           82        85
# 7  5/2/2017    mumbai           80        26

# %% [markdown]
# - **Simple Pivot table**

# %%
print("1st pivot table without passing aggfunc which by default is set to 'mean' ")
pt1= pd.pivot_table(df, index="city", columns="date", values=["temperature", "humidity"])
print(pt1)
# Out:
# 1st pivot table without passing aggfunc which by default is set to 'mean'
#          humidity          temperature
# date     5/1/2017 5/2/2017    5/1/2017 5/2/2017
# city
# mumbai       81.5     55.5        76.5     81.0
# new york     55.0     61.0        63.0     71.0

# %% [markdown]
# - **Using aggregate function**

# %%
print("2nd pivot table using aggfunc ")
pt2= pd.pivot_table(df, index="city", columns="date", aggfunc= "mean") #try using diff, count, sum etc.
print(pt2)
# Out:
# 2nd pivot table using aggfunc
#          humidity          temperature
# date     5/1/2017 5/2/2017    5/1/2017 5/2/2017
# city
# mumbai       81.5     55.5        76.5     81.0
# new york     55.0     61.0        63.0     71.0

# %% [markdown]
# - **by default margins=False changing it to True**
# - will add 'All' in row and also in column showing the average of the two values columnwise and rowwise

# %%
print("3rd pivot table using margins which by default is set to false")
pt3= pd.pivot_table(df, index='city', columns='date', aggfunc='mean', margins=True)
print(pt3)
# Out:
# 3rd pivot table using margins which by default is set to false
#          humidity                 temperature
# date     5/1/2017 5/2/2017    All    5/1/2017 5/2/2017     All
# city
# mumbai      81.50    55.50  68.50       76.50     81.0  78.750
# new york    55.00    61.00  58.00       63.00     71.0  67.000
# All         68.25    58.25  63.25       69.75     76.0  72.875

# %% [markdown]
# #### **Grouper() in pivot table**
# A Grouper allows the user to specify a groupby instruction for a target object

# %%
#creating dataframe
import pandas as pd
df= pd.read_csv("C:/Users/DELL/Downloads/weather3.csv")
print(df)
# Out:
#         date      city  temperature  humidity
# 0   5/1/2017  new york           65        56
# 1   5/2/2017  new york           61        54
# 2   5/3/2017  new york           70        60
# 3  12/1/2017  new york           30        50
# 4  12/2/2017  new york           28        52
# 5  12/3/2017  new york           25        51

# %% [markdown]
# **find average temperature of new york in month of may and average temperature in month of december. this is somethiong that you can do by using pure table grouper**

# %%
print("first converting the type of 'date' column from string to DateTime otherwise we will get error using grouper")
df['date']=pd.to_datetime(df['date'])
print(df)
# Out:
# first converting the type of 'date' column from string to DateTime otherwise we will get error using grouper
#         date      city  temperature  humidity
# 0 2017-05-01  new york           65        56
# 1 2017-05-02  new york           61        54
# 2 2017-05-03  new york           70        60
# 3 2017-12-01  new york           30        50
# 4 2017-12-02  new york           28        52
# 5 2017-12-03  new york           25        51

# %%
pt4= pd.pivot_table(df, index=pd.Grouper(freq='ME', key='date'), columns="city") #'ME' for month
print(pt4)
# Out:
#              humidity temperature
# city         new york    new york
# date
# 2017-05-31  56.666667   65.333333
# 2017-12-31  51.000000   27.666667

# %% [markdown]
# ## ii)Pandas.melt
# This function is useful to massage a DataFrame into a format where one or more columns are identifier variables (id_vars), while all other columns, considered measured variables (value_vars), are “unpivoted” to the row axis, leaving just two non-identifier columns, ‘variable’ and ‘value’.

# %% [markdown]
# **Creating a sample dataframe:**

# %%
import pandas as pd
df= pd.DataFrame({"Rollnum":[229,236,240,243,251],"Name":["Malaika Mehmood", "Rubaisha Munir", "Malaika Arshad", "Fariha Mehdi","Ayesha Nadeem"],"CGPA":[3.5,3.5,3.7,3.1,3.2],"Age":[21,20,21,22,21]})
print(df)
# Out:
#    Rollnum             Name  CGPA  Age
# 0      229  Malaika Mehmood   3.5   21
# 1      236   Rubaisha Munir   3.5   20
# 2      240   Malaika Arshad   3.7   21
# 3      243     Fariha Mehdi   3.1   22
# 4      251    Ayesha Nadeem   3.2   21

# %%
print("display only names")
m1= pd.melt(df, id_vars=["Rollnum"], value_vars=["Name"])
print(m1)
print("display cgpa and age as variable and value")
m2= pd.melt(df, id_vars=["Rollnum"], value_vars=["CGPA", "Age"])
print(m2)
# Out:
# display only names
#    Rollnum variable            value
# 0      229     Name  Malaika Mehmood
# 1      236     Name   Rubaisha Munir
# 2      240     Name   Malaika Arshad
# 3      243     Name     Fariha Mehdi
# 4      251     Name    Ayesha Nadeem
# display cgpa and age as variable and value
#    Rollnum variable  value
# 0      229     CGPA    3.5
# 1      236     CGPA    3.5
# 2      240     CGPA    3.7
# 3      243     CGPA    3.1
# 4      251     CGPA    3.2
# 5      229      Age   21.0
# 6      236      Age   20.0
# 7      240      Age   21.0
# 8      243      Age   22.0
# 9      251      Age   21.0

# %% [markdown]
# - **You can also set the name of the variable and value attributes**

# %%
print("setting the name of variable and value\n\n")
m3= pd.melt(df, id_vars=["Rollnum"], value_vars=["Name", "Age"], var_name="attributes", value_name="details")
print(m3)
# Out:
# setting the name of variable and value
#
#
#    Rollnum attributes          details
# 0      229       Name  Malaika Mehmood
# 1      236       Name   Rubaisha Munir
# 2      240       Name   Malaika Arshad
# 3      243       Name     Fariha Mehdi
# 4      251       Name    Ayesha Nadeem
# 5      229        Age               21
# 6      236        Age               20
# 7      240        Age               21
# 8      243        Age               22
# 9      251        Age               21
